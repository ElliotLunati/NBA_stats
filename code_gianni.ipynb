# %%
git init
# Out:
#   Cell In[5], line 1
#     git init
#         ^
# SyntaxError: invalid syntax

# %%
git pull https://github.com/ElliotLunati/NBA_stats.git
# Out:
#   Cell In[6], line 1
#     git pull https://github.com/ElliotLunati/NBA_stats.git
#         ^
# SyntaxError: invalid syntax

# %%
git config --global user.name "GianniPoull"
# Out:
#   Cell In[7], line 1
#     git config --global user.name "GianniPoull"
#         ^
# SyntaxError: invalid syntax

# %%
git config --global user.email "gigipoulinos@gmail.com"
# Out:
#   Cell In[8], line 1
#     git config --global user.email "gigipoulinos@gmail.com"
#         ^
# SyntaxError: invalid syntax
