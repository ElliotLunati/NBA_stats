# %% [markdown]
# # Installations

# %%
pip install -r requirements.txt
# Out:
# Collecting nba-api (from -r requirements.txt (line 5))
#   Downloading nba_api-1.10.2-py3-none-any.whl.metadata (5.8 kB)
# Collecting selenium (from -r requirements.txt (line 8))
#   Downloading selenium-4.38.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: beautifulsoup4 in /opt/python/lib/python3.13/site-packages (from -r requirements.txt (line 9)) (4.14.2)
# Requirement already satisfied: requests in /opt/python/lib/python3.13/site-packages (from -r requirements.txt (line 10)) (2.32.5)
# Requirement already satisfied: pandas in /opt/python/lib/python3.13/site-packages (from -r requirements.txt (line 13)) (2.3.3)
# Requirement already satisfied: scikit-learn in /opt/python/lib/python3.13/site-packages (from -r requirements.txt (line 14)) (1.7.2)
# Requirement already satisfied: matplotlib in /opt/python/lib/python3.13/site-packages (from -r requirements.txt (line 15)) (3.10.7)
# Requirement already satisfied: numpy>=2.1.0 in /opt/python/lib/python3.13/site-packages (from nba-api->-r requirements.txt (line 5)) (2.3.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/python/lib/python3.13/site-packages (from requests->-r requirements.txt (line 10)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/python/lib/python3.13/site-packages (from requests->-r requirements.txt (line 10)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/python/lib/python3.13/site-packages (from requests->-r requirements.txt (line 10)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/python/lib/python3.13/site-packages (from requests->-r requirements.txt (line 10)) (2025.10.5)
# Collecting trio<1.0,>=0.31.0 (from selenium->-r requirements.txt (line 8))
#   Downloading trio-0.32.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting trio-websocket<1.0,>=0.12.2 (from selenium->-r requirements.txt (line 8))
#   Downloading trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: typing_extensions<5.0,>=4.15.0 in /opt/python/lib/python3.13/site-packages (from selenium->-r requirements.txt (line 8)) (4.15.0)
# Requirement already satisfied: websocket-client<2.0,>=1.8.0 in /opt/python/lib/python3.13/site-packages (from selenium->-r requirements.txt (line 8)) (1.9.0)
# Requirement already satisfied: attrs>=23.2.0 in /opt/python/lib/python3.13/site-packages (from trio<1.0,>=0.31.0->selenium->-r requirements.txt (line 8)) (25.4.0)
# Requirement already satisfied: sortedcontainers in /opt/python/lib/python3.13/site-packages (from trio<1.0,>=0.31.0->selenium->-r requirements.txt (line 8)) (2.4.0)
# Collecting outcome (from trio<1.0,>=0.31.0->selenium->-r requirements.txt (line 8))
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in /opt/python/lib/python3.13/site-packages (from trio<1.0,>=0.31.0->selenium->-r requirements.txt (line 8)) (1.3.1)
# Collecting wsproto>=0.14 (from trio-websocket<1.0,>=0.12.2->selenium->-r requirements.txt (line 8))
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting pysocks!=1.5.7,<2.0,>=1.5.6 (from urllib3[socks]<3.0,>=2.5.0->selenium->-r requirements.txt (line 8))
#   Downloading PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: soupsieve>1.2 in /opt/python/lib/python3.13/site-packages (from beautifulsoup4->-r requirements.txt (line 9)) (2.8)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/python/lib/python3.13/site-packages (from pandas->-r requirements.txt (line 13)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/python/lib/python3.13/site-packages (from pandas->-r requirements.txt (line 13)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/python/lib/python3.13/site-packages (from pandas->-r requirements.txt (line 13)) (2025.2)
# Requirement already satisfied: scipy>=1.8.0 in /opt/python/lib/python3.13/site-packages (from scikit-learn->-r requirements.txt (line 14)) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /opt/python/lib/python3.13/site-packages (from scikit-learn->-r requirements.txt (line 14)) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/python/lib/python3.13/site-packages (from scikit-learn->-r requirements.txt (line 14)) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/python/lib/python3.13/site-packages (from matplotlib->-r requirements.txt (line 15)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/python/lib/python3.13/site-packages (from matplotlib->-r requirements.txt (line 15)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/python/lib/python3.13/site-packages (from matplotlib->-r requirements.txt (line 15)) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/python/lib/python3.13/site-packages (from matplotlib->-r requirements.txt (line 15)) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /opt/python/lib/python3.13/site-packages (from matplotlib->-r requirements.txt (line 15)) (25.0)
# Requirement already satisfied: pillow>=8 in /opt/python/lib/python3.13/site-packages (from matplotlib->-r requirements.txt (line 15)) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /opt/python/lib/python3.13/site-packages (from matplotlib->-r requirements.txt (line 15)) (3.2.5)
# Requirement already satisfied: six>=1.5 in /opt/python/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 13)) (1.17.0)
# Requirement already satisfied: h11<1,>=0.9.0 in /opt/python/lib/python3.13/site-packages (from wsproto>=0.14->trio-websocket<1.0,>=0.12.2->selenium->-r requirements.txt (line 8)) (0.16.0)
# Downloading nba_api-1.10.2-py3-none-any.whl (286 kB)
# Downloading selenium-4.38.0-py3-none-any.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 6.6 MB/s  0:00:01m eta 0:00:01
# Downloading trio-0.32.0-py3-none-any.whl (512 kB)
# Downloading trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Installing collected packages: wsproto, pysocks, outcome, trio, trio-websocket, nba-api, selenium
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [selenium]6/7 [selenium]
# Successfully installed nba-api-1.10.2 outcome-1.3.0.post0 pysocks-1.7.1 selenium-4.38.0 trio-0.32.0 trio-websocket-0.12.2 wsproto-1.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from build_nba_bdd import export_all_seasons, export_all_teams_seasons, export_all_salaries, scrape_mvp_data, merge_data

# %%
export_all_seasons()
# Out:
# ============================================================
# Récupération des statistiques de 1996--3 à 2024-25
# Types de saison: Regular Season, Playoffs
# Total: 58 fichiers à créer
# ============================================================
#
# [1/58] 1996-97 - Regular Season
# Récupération des statistiques de la saison 1996-97...
#
# Fichier './data/1996-97/Regular_Season/nba_players_stats_1996-97_Regular_Season.csv' créé avec succès!
# [2/58] 1996-97 - Playoffs
# Récupération des statistiques de la saison 1996-97...
#
# Fichier './data/1996-97/Playoffs/nba_players_stats_1996-97_Playoffs.csv' créé avec succès!
# [3/58] 1997-98 - Regular Season
# Récupération des statistiques de la saison 1997-98...
#
# Fichier './data/1997-98/Regular_Season/nba_players_stats_1997-98_Regular_Season.csv' créé avec succès!
# [4/58] 1997-98 - Playoffs
# Récupération des statistiques de la saison 1997-98...
#
# Fichier './data/1997-98/Playoffs/nba_players_stats_1997-98_Playoffs.csv' créé avec succès!
# [5/58] 1998-99 - Regular Season
# Récupération des statistiques de la saison 1998-99...
#
# Fichier './data/1998-99/Regular_Season/nba_players_stats_1998-99_Regular_Season.csv' créé avec succès!
# [6/58] 1998-99 - Playoffs
# Récupération des statistiques de la saison 1998-99...
#
# Fichier './data/1998-99/Playoffs/nba_players_stats_1998-99_Playoffs.csv' créé avec succès!
# [7/58] 1999-00 - Regular Season
# Récupération des statistiques de la saison 1999-00...
#
# Fichier './data/1999-00/Regular_Season/nba_players_stats_1999-00_Regular_Season.csv' créé avec succès!
# [8/58] 1999-00 - Playoffs
# Récupération des statistiques de la saison 1999-00...
#
# Fichier './data/1999-00/Playoffs/nba_players_stats_1999-00_Playoffs.csv' créé avec succès!
# [9/58] 2000-01 - Regular Season
# Récupération des statistiques de la saison 2000-01...
#
# Fichier './data/2000-01/Regular_Season/nba_players_stats_2000-01_Regular_Season.csv' créé avec succès!
# [10/58] 2000-01 - Playoffs
# Récupération des statistiques de la saison 2000-01...
#
# Fichier './data/2000-01/Playoffs/nba_players_stats_2000-01_Playoffs.csv' créé avec succès!
# [11/58] 2001-02 - Regular Season
# Récupération des statistiques de la saison 2001-02...
#
# Fichier './data/2001-02/Regular_Season/nba_players_stats_2001-02_Regular_Season.csv' créé avec succès!
# [12/58] 2001-02 - Playoffs
# Récupération des statistiques de la saison 2001-02...
#
# Fichier './data/2001-02/Playoffs/nba_players_stats_2001-02_Playoffs.csv' créé avec succès!
# [13/58] 2002-03 - Regular Season
# Récupération des statistiques de la saison 2002-03...
#
# Fichier './data/2002-03/Regular_Season/nba_players_stats_2002-03_Regular_Season.csv' créé avec succès!
# [14/58] 2002-03 - Playoffs
# Récupération des statistiques de la saison 2002-03...
#
# Fichier './data/2002-03/Playoffs/nba_players_stats_2002-03_Playoffs.csv' créé avec succès!
# [15/58] 2003-04 - Regular Season
# Récupération des statistiques de la saison 2003-04...
#
# Fichier './data/2003-04/Regular_Season/nba_players_stats_2003-04_Regular_Season.csv' créé avec succès!
# [16/58] 2003-04 - Playoffs
# Récupération des statistiques de la saison 2003-04...
#
# Fichier './data/2003-04/Playoffs/nba_players_stats_2003-04_Playoffs.csv' créé avec succès!
# [17/58] 2004-05 - Regular Season
# Récupération des statistiques de la saison 2004-05...
#
# Fichier './data/2004-05/Regular_Season/nba_players_stats_2004-05_Regular_Season.csv' créé avec succès!
# [18/58] 2004-05 - Playoffs
# Récupération des statistiques de la saison 2004-05...
#
# Fichier './data/2004-05/Playoffs/nba_players_stats_2004-05_Playoffs.csv' créé avec succès!
# [19/58] 2005-06 - Regular Season
# Récupération des statistiques de la saison 2005-06...
#
# Fichier './data/2005-06/Regular_Season/nba_players_stats_2005-06_Regular_Season.csv' créé avec succès!
# [20/58] 2005-06 - Playoffs
# Récupération des statistiques de la saison 2005-06...
#
# Fichier './data/2005-06/Playoffs/nba_players_stats_2005-06_Playoffs.csv' créé avec succès!
# [21/58] 2006-07 - Regular Season
# Récupération des statistiques de la saison 2006-07...
#
# Fichier './data/2006-07/Regular_Season/nba_players_stats_2006-07_Regular_Season.csv' créé avec succès!
# [22/58] 2006-07 - Playoffs
# Récupération des statistiques de la saison 2006-07...
#
# Fichier './data/2006-07/Playoffs/nba_players_stats_2006-07_Playoffs.csv' créé avec succès!
# [23/58] 2007-08 - Regular Season
# Récupération des statistiques de la saison 2007-08...
#
# Fichier './data/2007-08/Regular_Season/nba_players_stats_2007-08_Regular_Season.csv' créé avec succès!
# [24/58] 2007-08 - Playoffs
# Récupération des statistiques de la saison 2007-08...
#
# Fichier './data/2007-08/Playoffs/nba_players_stats_2007-08_Playoffs.csv' créé avec succès!
# [25/58] 2008-09 - Regular Season
# Récupération des statistiques de la saison 2008-09...
#
# Fichier './data/2008-09/Regular_Season/nba_players_stats_2008-09_Regular_Season.csv' créé avec succès!
# [26/58] 2008-09 - Playoffs
# Récupération des statistiques de la saison 2008-09...
#
# Fichier './data/2008-09/Playoffs/nba_players_stats_2008-09_Playoffs.csv' créé avec succès!
# [27/58] 2009-10 - Regular Season
# Récupération des statistiques de la saison 2009-10...
#
# Fichier './data/2009-10/Regular_Season/nba_players_stats_2009-10_Regular_Season.csv' créé avec succès!
# [28/58] 2009-10 - Playoffs
# Récupération des statistiques de la saison 2009-10...
#
# Fichier './data/2009-10/Playoffs/nba_players_stats_2009-10_Playoffs.csv' créé avec succès!
# [29/58] 2010-11 - Regular Season
# Récupération des statistiques de la saison 2010-11...
#
# Fichier './data/2010-11/Regular_Season/nba_players_stats_2010-11_Regular_Season.csv' créé avec succès!
# [30/58] 2010-11 - Playoffs
# Récupération des statistiques de la saison 2010-11...
#
# Fichier './data/2010-11/Playoffs/nba_players_stats_2010-11_Playoffs.csv' créé avec succès!
# [31/58] 2011-12 - Regular Season
# Récupération des statistiques de la saison 2011-12...
#
# Fichier './data/2011-12/Regular_Season/nba_players_stats_2011-12_Regular_Season.csv' créé avec succès!
# [32/58] 2011-12 - Playoffs
# Récupération des statistiques de la saison 2011-12...
#
# Fichier './data/2011-12/Playoffs/nba_players_stats_2011-12_Playoffs.csv' créé avec succès!
# [33/58] 2012-13 - Regular Season
# Récupération des statistiques de la saison 2012-13...
#
# Fichier './data/2012-13/Regular_Season/nba_players_stats_2012-13_Regular_Season.csv' créé avec succès!
# [34/58] 2012-13 - Playoffs
# Récupération des statistiques de la saison 2012-13...
#
# Fichier './data/2012-13/Playoffs/nba_players_stats_2012-13_Playoffs.csv' créé avec succès!
# [35/58] 2013-14 - Regular Season
# Récupération des statistiques de la saison 2013-14...
#
# Fichier './data/2013-14/Regular_Season/nba_players_stats_2013-14_Regular_Season.csv' créé avec succès!
# [36/58] 2013-14 - Playoffs
# Récupération des statistiques de la saison 2013-14...
#
# Fichier './data/2013-14/Playoffs/nba_players_stats_2013-14_Playoffs.csv' créé avec succès!
# [37/58] 2014-15 - Regular Season
# Récupération des statistiques de la saison 2014-15...
#
# Fichier './data/2014-15/Regular_Season/nba_players_stats_2014-15_Regular_Season.csv' créé avec succès!
# [38/58] 2014-15 - Playoffs
# Récupération des statistiques de la saison 2014-15...
#
# Fichier './data/2014-15/Playoffs/nba_players_stats_2014-15_Playoffs.csv' créé avec succès!
# [39/58] 2015-16 - Regular Season
# Récupération des statistiques de la saison 2015-16...
#
# Fichier './data/2015-16/Regular_Season/nba_players_stats_2015-16_Regular_Season.csv' créé avec succès!
# [40/58] 2015-16 - Playoffs
# Récupération des statistiques de la saison 2015-16...
#
# Fichier './data/2015-16/Playoffs/nba_players_stats_2015-16_Playoffs.csv' créé avec succès!
# [41/58] 2016-17 - Regular Season
# Récupération des statistiques de la saison 2016-17...
#
# Fichier './data/2016-17/Regular_Season/nba_players_stats_2016-17_Regular_Season.csv' créé avec succès!
# [42/58] 2016-17 - Playoffs
# Récupération des statistiques de la saison 2016-17...
#
# Fichier './data/2016-17/Playoffs/nba_players_stats_2016-17_Playoffs.csv' créé avec succès!
# [43/58] 2017-18 - Regular Season
# Récupération des statistiques de la saison 2017-18...
#
# Fichier './data/2017-18/Regular_Season/nba_players_stats_2017-18_Regular_Season.csv' créé avec succès!
# [44/58] 2017-18 - Playoffs
# Récupération des statistiques de la saison 2017-18...
#
# Fichier './data/2017-18/Playoffs/nba_players_stats_2017-18_Playoffs.csv' créé avec succès!
# [45/58] 2018-19 - Regular Season
# Récupération des statistiques de la saison 2018-19...
#
# Fichier './data/2018-19/Regular_Season/nba_players_stats_2018-19_Regular_Season.csv' créé avec succès!
# [46/58] 2018-19 - Playoffs
# Récupération des statistiques de la saison 2018-19...
#
# Fichier './data/2018-19/Playoffs/nba_players_stats_2018-19_Playoffs.csv' créé avec succès!
# [47/58] 2019-20 - Regular Season
# Récupération des statistiques de la saison 2019-20...
#
# Fichier './data/2019-20/Regular_Season/nba_players_stats_2019-20_Regular_Season.csv' créé avec succès!
# [48/58] 2019-20 - Playoffs
# Récupération des statistiques de la saison 2019-20...
#
# Fichier './data/2019-20/Playoffs/nba_players_stats_2019-20_Playoffs.csv' créé avec succès!
# [49/58] 2020-21 - Regular Season
# Récupération des statistiques de la saison 2020-21...
#
# Fichier './data/2020-21/Regular_Season/nba_players_stats_2020-21_Regular_Season.csv' créé avec succès!
# [50/58] 2020-21 - Playoffs
# Récupération des statistiques de la saison 2020-21...
#
# Fichier './data/2020-21/Playoffs/nba_players_stats_2020-21_Playoffs.csv' créé avec succès!
# [51/58] 2021-22 - Regular Season
# Récupération des statistiques de la saison 2021-22...
#
# Fichier './data/2021-22/Regular_Season/nba_players_stats_2021-22_Regular_Season.csv' créé avec succès!
# [52/58] 2021-22 - Playoffs
# Récupération des statistiques de la saison 2021-22...
#
# Fichier './data/2021-22/Playoffs/nba_players_stats_2021-22_Playoffs.csv' créé avec succès!
# [53/58] 2022-23 - Regular Season
# Récupération des statistiques de la saison 2022-23...
#
# Fichier './data/2022-23/Regular_Season/nba_players_stats_2022-23_Regular_Season.csv' créé avec succès!
# [54/58] 2022-23 - Playoffs
# Récupération des statistiques de la saison 2022-23...
#
# Fichier './data/2022-23/Playoffs/nba_players_stats_2022-23_Playoffs.csv' créé avec succès!
# [55/58] 2023-24 - Regular Season
# Récupération des statistiques de la saison 2023-24...
#
# Fichier './data/2023-24/Regular_Season/nba_players_stats_2023-24_Regular_Season.csv' créé avec succès!
# [56/58] 2023-24 - Playoffs
# Récupération des statistiques de la saison 2023-24...
#
# Fichier './data/2023-24/Playoffs/nba_players_stats_2023-24_Playoffs.csv' créé avec succès!
# [57/58] 2024-25 - Regular Season
# Récupération des statistiques de la saison 2024-25...
#
# Fichier './data/2024-25/Regular_Season/nba_players_stats_2024-25_Regular_Season.csv' créé avec succès!
# [58/58] 2024-25 - Playoffs
# Récupération des statistiques de la saison 2024-25...
#
# Fichier './data/2024-25/Playoffs/nba_players_stats_2024-25_Playoffs.csv' créé avec succès!
#
# ============================================================
# Récupération terminée!
# 58 fichiers créés sur 58 attendus
# ============================================================
# {'1996-97_Regular Season': {'path': './data/1996-97/Regular_Season/nba_players_stats_1996-97_Regular_Season.csv',
#   'players_count': 441},
#  '1996-97_Playoffs': {'path': './data/1996-97/Playoffs/nba_players_stats_1996-97_Playoffs.csv',
#   'players_count': 189},
#  '1997-98_Regular Season': {'path': './data/1997-98/Regular_Season/nba_players_stats_1997-98_Regular_Season.csv',
#   'players_count': 439},
#  '1997-98_Playoffs': {'path': './data/1997-98/Playoffs/nba_players_stats_1997-98_Playoffs.csv',
#   'players_count': 190},
#  '1998-99_Regular Season': {'path': './data/1998-99/Regular_Season/nba_players_stats_1998-99_Regular_Season.csv',
#   'players_count': 440},
#  '1998-99_Playoffs': {'path': './data/1998-99/Playoffs/nba_players_stats_1998-99_Playoffs.csv',
#   'players_count': 189},
#  '1999-00_Regular Season': {'path': './data/1999-00/Regular_Season/nba_players_stats_1999-00_Regular_Season.csv',
#   'players_count': 439},
#  '1999-00_Playoffs': {'path': './data/1999-00/Playoffs/nba_players_stats_1999-00_Playoffs.csv',
#   'players_count': 181},
#  '2000-01_Regular Season': {'path': './data/2000-01/Regular_Season/nba_players_stats_2000-01_Regular_Season.csv',
#   'players_count': 441},
#  '2000-01_Playoffs': {'path': './data/2000-01/Playoffs/nba_players_stats_2000-01_Playoffs.csv',
#   'players_count': 190},
#  '2001-02_Regular Season': {'path': './data/2001-02/Regular_Season/nba_players_stats_2001-02_Regular_Season.csv',
#   'players_count': 440},
#  '2001-02_Playoffs': {'path': './data/2001-02/Playoffs/nba_players_stats_2001-02_Playoffs.csv',
#   'players_count': 186},
#  '2002-03_Regular Season': {'path': './data/2002-03/Regular_Season/nba_players_stats_2002-03_Regular_Season.csv',
#   'players_count': 428},
#  '2002-03_Playoffs': {'path': './data/2002-03/Playoffs/nba_players_stats_2002-03_Playoffs.csv',
#   'players_count': 187},
#  '2003-04_Regular Season': {'path': './data/2003-04/Regular_Season/nba_players_stats_2003-04_Regular_Season.csv',
#   'players_count': 442},
#  '2003-04_Playoffs': {'path': './data/2003-04/Playoffs/nba_players_stats_2003-04_Playoffs.csv',
#   'players_count': 189},
#  '2004-05_Regular Season': {'path': './data/2004-05/Regular_Season/nba_players_stats_2004-05_Regular_Season.csv',
#   'players_count': 464},
#  '2004-05_Playoffs': {'path': './data/2004-05/Playoffs/nba_players_stats_2004-05_Playoffs.csv',
#   'players_count': 188},
#  '2005-06_Regular Season': {'path': './data/2005-06/Regular_Season/nba_players_stats_2005-06_Regular_Season.csv',
#   'players_count': 458},
#  '2005-06_Playoffs': {'path': './data/2005-06/Playoffs/nba_players_stats_2005-06_Playoffs.csv',
#   'players_count': 195},
#  '2006-07_Regular Season': {'path': './data/2006-07/Regular_Season/nba_players_stats_2006-07_Regular_Season.csv',
#   'players_count': 458},
#  '2006-07_Playoffs': {'path': './data/2006-07/Playoffs/nba_players_stats_2006-07_Playoffs.csv',
#   'players_count': 191},
#  '2007-08_Regular Season': {'path': './data/2007-08/Regular_Season/nba_players_stats_2007-08_Regular_Season.csv',
#   'players_count': 451},
#  '2007-08_Playoffs': {'path': './data/2007-08/Playoffs/nba_players_stats_2007-08_Playoffs.csv',
#   'players_count': 202},
#  '2008-09_Regular Season': {'path': './data/2008-09/Regular_Season/nba_players_stats_2008-09_Regular_Season.csv',
#   'players_count': 445},
#  '2008-09_Playoffs': {'path': './data/2008-09/Playoffs/nba_players_stats_2008-09_Playoffs.csv',
#   'players_count': 199},
#  '2009-10_Regular Season': {'path': './data/2009-10/Regular_Season/nba_players_stats_2009-10_Regular_Season.csv',
#   'players_count': 442},
#  '2009-10_Playoffs': {'path': './data/2009-10/Playoffs/nba_players_stats_2009-10_Playoffs.csv',
#   'players_count': 199},
#  '2010-11_Regular Season': {'path': './data/2010-11/Regular_Season/nba_players_stats_2010-11_Regular_Season.csv',
#   'players_count': 452},
#  '2010-11_Playoffs': {'path': './data/2010-11/Playoffs/nba_players_stats_2010-11_Playoffs.csv',
#   'players_count': 194},
#  '2011-12_Regular Season': {'path': './data/2011-12/Regular_Season/nba_players_stats_2011-12_Regular_Season.csv',
#   'players_count': 478},
#  '2011-12_Playoffs': {'path': './data/2011-12/Playoffs/nba_players_stats_2011-12_Playoffs.csv',
#   'players_count': 204},
#  '2012-13_Regular Season': {'path': './data/2012-13/Regular_Season/nba_players_stats_2012-13_Regular_Season.csv',
#   'players_count': 469},
#  '2012-13_Playoffs': {'path': './data/2012-13/Playoffs/nba_players_stats_2012-13_Playoffs.csv',
#   'players_count': 209},
#  '2013-14_Regular Season': {'path': './data/2013-14/Regular_Season/nba_players_stats_2013-14_Regular_Season.csv',
#   'players_count': 482},
#  '2013-14_Playoffs': {'path': './data/2013-14/Playoffs/nba_players_stats_2013-14_Playoffs.csv',
#   'players_count': 204},
#  '2014-15_Regular Season': {'path': './data/2014-15/Regular_Season/nba_players_stats_2014-15_Regular_Season.csv',
#   'players_count': 492},
#  '2014-15_Playoffs': {'path': './data/2014-15/Playoffs/nba_players_stats_2014-15_Playoffs.csv',
#   'players_count': 208},
#  '2015-16_Regular Season': {'path': './data/2015-16/Regular_Season/nba_players_stats_2015-16_Regular_Season.csv',
#   'players_count': 476},
#  '2015-16_Playoffs': {'path': './data/2015-16/Playoffs/nba_players_stats_2015-16_Playoffs.csv',
#   'players_count': 215},
#  '2016-17_Regular Season': {'path': './data/2016-17/Regular_Season/nba_players_stats_2016-17_Regular_Season.csv',
#   'players_count': 486},
#  '2016-17_Playoffs': {'path': './data/2016-17/Playoffs/nba_players_stats_2016-17_Playoffs.csv',
#   'players_count': 215},
#  '2017-18_Regular Season': {'path': './data/2017-18/Regular_Season/nba_players_stats_2017-18_Regular_Season.csv',
#   'players_count': 540},
#  '2017-18_Playoffs': {'path': './data/2017-18/Playoffs/nba_players_stats_2017-18_Playoffs.csv',
#   'players_count': 210},
#  '2018-19_Regular Season': {'path': './data/2018-19/Regular_Season/nba_players_stats_2018-19_Regular_Season.csv',
#   'players_count': 530},
#  '2018-19_Playoffs': {'path': './data/2018-19/Playoffs/nba_players_stats_2018-19_Playoffs.csv',
#   'players_count': 212},
#  '2019-20_Regular Season': {'path': './data/2019-20/Regular_Season/nba_players_stats_2019-20_Regular_Season.csv',
#   'players_count': 529},
#  '2019-20_Playoffs': {'path': './data/2019-20/Playoffs/nba_players_stats_2019-20_Playoffs.csv',
#   'players_count': 217},
#  '2020-21_Regular Season': {'path': './data/2020-21/Regular_Season/nba_players_stats_2020-21_Regular_Season.csv',
#   'players_count': 540},
#  '2020-21_Playoffs': {'path': './data/2020-21/Playoffs/nba_players_stats_2020-21_Playoffs.csv',
#   'players_count': 239},
#  '2021-22_Regular Season': {'path': './data/2021-22/Regular_Season/nba_players_stats_2021-22_Regular_Season.csv',
#   'players_count': 605},
#  '2021-22_Playoffs': {'path': './data/2021-22/Playoffs/nba_players_stats_2021-22_Playoffs.csv',
#   'players_count': 217},
#  '2022-23_Regular Season': {'path': './data/2022-23/Regular_Season/nba_players_stats_2022-23_Regular_Season.csv',
#   'players_count': 539},
#  '2022-23_Playoffs': {'path': './data/2022-23/Playoffs/nba_players_stats_2022-23_Playoffs.csv',
#   'players_count': 217},
#  '2023-24_Regular Season': {'path': './data/2023-24/Regular_Season/nba_players_stats_2023-24_Regular_Season.csv',
#   'players_count': 572},
#  '2023-24_Playoffs': {'path': './data/2023-24/Playoffs/nba_players_stats_2023-24_Playoffs.csv',
#   'players_count': 214},
#  '2024-25_Regular Season': {'path': './data/2024-25/Regular_Season/nba_players_stats_2024-25_Regular_Season.csv',
#   'players_count': 569},
#  '2024-25_Playoffs': {'path': './data/2024-25/Playoffs/nba_players_stats_2024-25_Playoffs.csv',
#   'players_count': 219}}

# %%
export_all_teams_seasons() # 5min environ
# Out:
# ============================================================
# Récupération des statistiques des ÉQUIPES NBA
# De 1996-97 à 2024-25
# Types de saison: Regular Season, Playoffs
# Total: 58 fichiers à créer
# ============================================================
#
# [1/58] 1996-97 - Regular Season
# Récupération des statistiques des équipes pour la saison 1996-97...
#
# Fichier './data/1996-97/Regular_Season/nba_teams_stats_1996-97_Regular_Season.csv' créé avec succès! (29 équipes NBA)
# [2/58] 1996-97 - Playoffs
# Récupération des statistiques des équipes pour la saison 1996-97...
#
# Fichier './data/1996-97/Playoffs/nba_teams_stats_1996-97_Playoffs.csv' créé avec succès! (16 équipes NBA)
# [3/58] 1997-98 - Regular Season
# Récupération des statistiques des équipes pour la saison 1997-98...
#   8 équipe(s) non-NBA filtrée(s) (WNBA/G-League)
#
# Fichier './data/1997-98/Regular_Season/nba_teams_stats_1997-98_Regular_Season.csv' créé avec succès! (29 équipes NBA)
# [4/58] 1997-98 - Playoffs
# Récupération des statistiques des équipes pour la saison 1997-98...
#
# Fichier './data/1997-98/Playoffs/nba_teams_stats_1997-98_Playoffs.csv' créé avec succès! (16 équipes NBA)
# [5/58] 1998-99 - Regular Season
# Récupération des statistiques des équipes pour la saison 1998-99...
#   10 équipe(s) non-NBA filtrée(s) (WNBA/G-League)
#
# Fichier './data/1998-99/Regular_Season/nba_teams_stats_1998-99_Regular_Season.csv' créé avec succès! (29 équipes NBA)
# [6/58] 1998-99 - Playoffs
# Récupération des statistiques des équipes pour la saison 1998-99...
#
# Fichier './data/1998-99/Playoffs/nba_teams_stats_1998-99_Playoffs.csv' créé avec succès! (16 équipes NBA)
# [7/58] 1999-00 - Regular Season
# Récupération des statistiques des équipes pour la saison 1999-00...
#   12 équipe(s) non-NBA filtrée(s) (WNBA/G-League)
#
# Fichier './data/1999-00/Regular_Season/nba_teams_stats_1999-00_Regular_Season.csv' créé avec succès! (29 équipes NBA)
# [8/58] 1999-00 - Playoffs
# Récupération des statistiques des équipes pour la saison 1999-00...
#
# Fichier './data/1999-00/Playoffs/nba_teams_stats_1999-00_Playoffs.csv' créé avec succès! (16 équipes NBA)
# [9/58] 2000-01 - Regular Season
# Récupération des statistiques des équipes pour la saison 2000-01...
#   16 équipe(s) non-NBA filtrée(s) (WNBA/G-League)
#
# Fichier './data/2000-01/Regular_Season/nba_teams_stats_2000-01_Regular_Season.csv' créé avec succès! (29 équipes NBA)
# [10/58] 2000-01 - Playoffs
# Récupération des statistiques des équipes pour la saison 2000-01...
#
# Fichier './data/2000-01/Playoffs/nba_teams_stats_2000-01_Playoffs.csv' créé avec succès! (16 équipes NBA)
# [11/58] 2001-02 - Regular Season
# Récupération des statistiques des équipes pour la saison 2001-02...
#   16 équipe(s) non-NBA filtrée(s) (WNBA/G-League)
#
# Fichier './data/2001-02/Regular_Season/nba_teams_stats_2001-02_Regular_Season.csv' créé avec succès! (29 équipes NBA)
# [12/58] 2001-02 - Playoffs
# Récupération des statistiques des équipes pour la saison 2001-02...
#   8 équipe(s) non-NBA filtrée(s) (WNBA/G-League)
#
# Fichier './data/2001-02/Playoffs/nba_teams_stats_2001-02_Playoffs.csv' créé avec succès! (16 équipes NBA)
# [13/58] 2002-03 - Regular Season
# Récupération des statistiques des équipes pour la saison 2002-03...
#   16 équipe(s) non-NBA filtrée(s) (WNBA/G-League)
#
# Fichier './data/2002-03/Regular_Season/nba_teams_stats_2002-03_Regular_Season.csv' créé avec succès! (29 équipes NBA)
# [14/58] 2002-03 - Playoffs
# Récupération des statistiques des équipes pour la saison 2002-03...
#   8 équipe(s) non-NBA filtrée(s) (WNBA/G-League)
#
# Fichier './data/2002-03/Playoffs/nba_teams_stats_2002-03_Playoffs.csv' créé avec succès! (16 équipes NBA)
# [15/58] 2003-04 - Regular Season
# Récupération des statistiques des équipes pour la saison 2003-04...
#   15 équipe(s) non-NBA filtrée(s) (WNBA/G-League)
#
# Fichier './data/2003-04/Regular_Season/nba_teams_stats_2003-04_Regular_Season.csv' créé avec succès! (29 équipes NBA)
# [16/58] 2003-04 - Playoffs
# Récupération des statistiques des équipes pour la saison 2003-04...
#   8 équipe(s) non-NBA filtrée(s) (WNBA/G-League)
#
# Fichier './data/2003-04/Playoffs/nba_teams_stats_2003-04_Playoffs.csv' créé avec succès! (16 équipes NBA)
# [17/58] 2004-05 - Regular Season
# Récupération des statistiques des équipes pour la saison 2004-05...
#   19 équipe(s) non-NBA filtrée(s) (WNBA/G-League)
#
# Fichier './data/2004-05/Regular_Season/nba_teams_stats_2004-05_Regular_Season.csv' créé avec succès! (30 équipes NBA)
# [18/58] 2004-05 - Playoffs
# Récupération des statistiques des équipes pour la saison 2004-05...
#   8 équipe(s) non-NBA filtrée(s) (WNBA/G-League)
#
# Fichier './data/2004-05/Playoffs/nba_teams_stats_2004-05_Playoffs.csv' créé avec succès! (16 équipes NBA)
# [19/58] 2005-06 - Regular Season
# Récupération des statistiques des équipes pour la saison 2005-06...
#   21 équipe(s) non-NBA filtrée(s) (WNBA/G-League)
#
# Fichier './data/2005-06/Regular_Season/nba_teams_stats_2005-06_Regular_Season.csv' créé avec succès! (30 équipes NBA)
# [20/58] 2005-06 - Playoffs
# Récupération des statistiques des équipes pour la saison 2005-06...
#   12 équipe(s) non-NBA filtrée(s) (WNBA/G-League)
#
# Fichier './data/2005-06/Playoffs/nba_teams_stats_2005-06_Playoffs.csv' créé avec succès! (16 équipes NBA)
# [21/58] 2006-07 - Regular Season
# Récupération des statistiques des équipes pour la saison 2006-07...
#   26 équipe(s) non-NBA filtrée(s) (WNBA/G-League)
#
# Fichier './data/2006-07/Regular_Season/nba_teams_stats_2006-07_Regular_Season.csv' créé avec succès! (30 équipes NBA)
# [22/58] 2006-07 - Playoffs
# Récupération des statistiques des équipes pour la saison 2006-07...
#   14 équipe(s) non-NBA filtrée(s) (WNBA/G-League)
#
# Fichier './data/2006-07/Playoffs/nba_teams_stats_2006-07_Playoffs.csv' créé avec succès! (16 équipes NBA)
# [23/58] 2007-08 - Regular Season
# Récupération des statistiques des équipes pour la saison 2007-08...
#   28 équipe(s) non-NBA filtrée(s) (WNBA/G-League)
#   21 ligne(s) avec TEAM_NAME vide supprimée(s)
#
# Fichier './data/2007-08/Regular_Season/nba_teams_stats_2007-08_Regular_Season.csv' créé avec succès! (30 équipes NBA)
# [24/58] 2007-08 - Playoffs
# Récupération des statistiques des équipes pour la saison 2007-08...
#   14 équipe(s) non-NBA filtrée(s) (WNBA/G-League)
#
# Fichier './data/2007-08/Playoffs/nba_teams_stats_2007-08_Playoffs.csv' créé avec succès! (16 équipes NBA)
# [25/58] 2008-09 - Regular Season
# Récupération des statistiques des équipes pour la saison 2008-09...
#   30 équipe(s) non-NBA filtrée(s) (WNBA/G-League)
#   21 ligne(s) avec TEAM_NAME vide supprimée(s)
#
# Fichier './data/2008-09/Regular_Season/nba_teams_stats_2008-09_Regular_Season.csv' créé avec succès! (30 équipes NBA)
# [26/58] 2008-09 - Playoffs
# Récupération des statistiques des équipes pour la saison 2008-09...
#   16 équipe(s) non-NBA filtrée(s) (WNBA/G-League)
#
# Fichier './data/2008-09/Playoffs/nba_teams_stats_2008-09_Playoffs.csv' créé avec succès! (16 équipes NBA)
# [27/58] 2009-10 - Regular Season
# Récupération des statistiques des équipes pour la saison 2009-10...
#   30 équipe(s) non-NBA filtrée(s) (WNBA/G-League)
#   21 ligne(s) avec TEAM_NAME vide supprimée(s)
#
# Fichier './data/2009-10/Regular_Season/nba_teams_stats_2009-10_Regular_Season.csv' créé avec succès! (30 équipes NBA)
# [28/58] 2009-10 - Playoffs
# Récupération des statistiques des équipes pour la saison 2009-10...
#   16 équipe(s) non-NBA filtrée(s) (WNBA/G-League)
#
# Fichier './data/2009-10/Playoffs/nba_teams_stats_2009-10_Playoffs.csv' créé avec succès! (16 équipes NBA)
# [29/58] 2010-11 - Regular Season
# Récupération des statistiques des équipes pour la saison 2010-11...
#   29 équipe(s) non-NBA filtrée(s) (WNBA/G-League)
#   30 ligne(s) avec TEAM_NAME vide supprimée(s)
#
# Fichier './data/2010-11/Regular_Season/nba_teams_stats_2010-11_Regular_Season.csv' créé avec succès! (30 équipes NBA)
# [30/58] 2010-11 - Playoffs
# Récupération des statistiques des équipes pour la saison 2010-11...
#   16 équipe(s) non-NBA filtrée(s) (WNBA/G-League)
#
# Fichier './data/2010-11/Playoffs/nba_teams_stats_2010-11_Playoffs.csv' créé avec succès! (16 équipes NBA)
# [31/58] 2011-12 - Regular Season
# Récupération des statistiques des équipes pour la saison 2011-12...
#   28 équipe(s) non-NBA filtrée(s) (WNBA/G-League)
#
# Fichier './data/2011-12/Regular_Season/nba_teams_stats_2011-12_Regular_Season.csv' créé avec succès! (30 équipes NBA)
# [32/58] 2011-12 - Playoffs
# Récupération des statistiques des équipes pour la saison 2011-12...
#   16 équipe(s) non-NBA filtrée(s) (WNBA/G-League)
#
# Fichier './data/2011-12/Playoffs/nba_teams_stats_2011-12_Playoffs.csv' créé avec succès! (16 équipes NBA)
# [33/58] 2012-13 - Regular Season
# Récupération des statistiques des équipes pour la saison 2012-13...
#   29 équipe(s) non-NBA filtrée(s) (WNBA/G-League)
#   30 ligne(s) avec TEAM_NAME vide supprimée(s)
#
# Fichier './data/2012-13/Regular_Season/nba_teams_stats_2012-13_Regular_Season.csv' créé avec succès! (30 équipes NBA)
# [34/58] 2012-13 - Playoffs
# Récupération des statistiques des équipes pour la saison 2012-13...
#   16 équipe(s) non-NBA filtrée(s) (WNBA/G-League)
#
# Fichier './data/2012-13/Playoffs/nba_teams_stats_2012-13_Playoffs.csv' créé avec succès! (16 équipes NBA)
# [35/58] 2013-14 - Regular Season
# Récupération des statistiques des équipes pour la saison 2013-14...
#   30 équipe(s) non-NBA filtrée(s) (WNBA/G-League)
#   30 ligne(s) avec TEAM_NAME vide supprimée(s)
#
# Fichier './data/2013-14/Regular_Season/nba_teams_stats_2013-14_Regular_Season.csv' créé avec succès! (30 équipes NBA)
# [36/58] 2013-14 - Playoffs
# Récupération des statistiques des équipes pour la saison 2013-14...
#   16 équipe(s) non-NBA filtrée(s) (WNBA/G-League)
#
# Fichier './data/2013-14/Playoffs/nba_teams_stats_2013-14_Playoffs.csv' créé avec succès! (16 équipes NBA)
# [37/58] 2014-15 - Regular Season
# Récupération des statistiques des équipes pour la saison 2014-15...
#   31 équipe(s) non-NBA filtrée(s) (WNBA/G-League)
#   30 ligne(s) avec TEAM_NAME vide supprimée(s)
#
# Fichier './data/2014-15/Regular_Season/nba_teams_stats_2014-15_Regular_Season.csv' créé avec succès! (30 équipes NBA)
# [38/58] 2014-15 - Playoffs
# Récupération des statistiques des équipes pour la saison 2014-15...
#   16 équipe(s) non-NBA filtrée(s) (WNBA/G-League)
#
# Fichier './data/2014-15/Playoffs/nba_teams_stats_2014-15_Playoffs.csv' créé avec succès! (16 équipes NBA)
# [39/58] 2015-16 - Regular Season
# Récupération des statistiques des équipes pour la saison 2015-16...
#   34 équipe(s) non-NBA filtrée(s) (WNBA/G-League)
#   29 ligne(s) avec TEAM_NAME vide supprimée(s)
#
# Fichier './data/2015-16/Regular_Season/nba_teams_stats_2015-16_Regular_Season.csv' créé avec succès! (30 équipes NBA)
# [40/58] 2015-16 - Playoffs
# Récupération des statistiques des équipes pour la saison 2015-16...
#   16 équipe(s) non-NBA filtrée(s) (WNBA/G-League)
#
# Fichier './data/2015-16/Playoffs/nba_teams_stats_2015-16_Playoffs.csv' créé avec succès! (16 équipes NBA)
# [41/58] 2016-17 - Regular Season
# Récupération des statistiques des équipes pour la saison 2016-17...
#   37 équipe(s) non-NBA filtrée(s) (WNBA/G-League)
#   29 ligne(s) avec TEAM_NAME vide supprimée(s)
#
# Fichier './data/2016-17/Regular_Season/nba_teams_stats_2016-17_Regular_Season.csv' créé avec succès! (30 équipes NBA)
# [42/58] 2016-17 - Playoffs
# Récupération des statistiques des équipes pour la saison 2016-17...
#   16 équipe(s) non-NBA filtrée(s) (WNBA/G-League)
#
# Fichier './data/2016-17/Playoffs/nba_teams_stats_2016-17_Playoffs.csv' créé avec succès! (16 équipes NBA)
# [43/58] 2017-18 - Regular Season
# Récupération des statistiques des équipes pour la saison 2017-18...
#   38 équipe(s) non-NBA filtrée(s) (WNBA/G-League)
#   30 ligne(s) avec TEAM_NAME vide supprimée(s)
#
# Fichier './data/2017-18/Regular_Season/nba_teams_stats_2017-18_Regular_Season.csv' créé avec succès! (30 équipes NBA)
# [44/58] 2017-18 - Playoffs
# Récupération des statistiques des équipes pour la saison 2017-18...
#   20 équipe(s) non-NBA filtrée(s) (WNBA/G-League)
#
# Fichier './data/2017-18/Playoffs/nba_teams_stats_2017-18_Playoffs.csv' créé avec succès! (16 équipes NBA)
# [45/58] 2018-19 - Regular Season
# Récupération des statistiques des équipes pour la saison 2018-19...
#   39 équipe(s) non-NBA filtrée(s) (WNBA/G-League)
#   30 ligne(s) avec TEAM_NAME vide supprimée(s)
#
# Fichier './data/2018-19/Regular_Season/nba_teams_stats_2018-19_Regular_Season.csv' créé avec succès! (30 équipes NBA)
# [46/58] 2018-19 - Playoffs
# Récupération des statistiques des équipes pour la saison 2018-19...
#   20 équipe(s) non-NBA filtrée(s) (WNBA/G-League)
#
# Fichier './data/2018-19/Playoffs/nba_teams_stats_2018-19_Playoffs.csv' créé avec succès! (16 équipes NBA)
# [47/58] 2019-20 - Regular Season
# Récupération des statistiques des équipes pour la saison 2019-20...
#   63 équipe(s) non-NBA filtrée(s) (WNBA/G-League)
#
# Fichier './data/2019-20/Regular_Season/nba_teams_stats_2019-20_Regular_Season.csv' créé avec succès! (30 équipes NBA)
# [48/58] 2019-20 - Playoffs
# Récupération des statistiques des équipes pour la saison 2019-20...
#   16 équipe(s) non-NBA filtrée(s) (WNBA/G-League)
#
# Fichier './data/2019-20/Playoffs/nba_teams_stats_2019-20_Playoffs.csv' créé avec succès! (16 équipes NBA)
# [49/58] 2020-21 - Regular Season
# Récupération des statistiques des équipes pour la saison 2020-21...
#   30 équipe(s) non-NBA filtrée(s) (WNBA/G-League)
#
# Fichier './data/2020-21/Regular_Season/nba_teams_stats_2020-21_Regular_Season.csv' créé avec succès! (30 équipes NBA)
# [50/58] 2020-21 - Playoffs
# Récupération des statistiques des équipes pour la saison 2020-21...
#   16 équipe(s) non-NBA filtrée(s) (WNBA/G-League)
#
# Fichier './data/2020-21/Playoffs/nba_teams_stats_2020-21_Playoffs.csv' créé avec succès! (16 équipes NBA)
# [51/58] 2021-22 - Regular Season
# Récupération des statistiques des équipes pour la saison 2021-22...
#   65 équipe(s) non-NBA filtrée(s) (WNBA/G-League)
#
# Fichier './data/2021-22/Regular_Season/nba_teams_stats_2021-22_Regular_Season.csv' créé avec succès! (30 équipes NBA)
# [52/58] 2021-22 - Playoffs
# Récupération des statistiques des équipes pour la saison 2021-22...
#   32 équipe(s) non-NBA filtrée(s) (WNBA/G-League)
#
# Fichier './data/2021-22/Playoffs/nba_teams_stats_2021-22_Playoffs.csv' créé avec succès! (16 équipes NBA)
# [53/58] 2022-23 - Regular Season
# Récupération des statistiques des équipes pour la saison 2022-23...
#   42 équipe(s) non-NBA filtrée(s) (WNBA/G-League)
#
# Fichier './data/2022-23/Regular_Season/nba_teams_stats_2022-23_Regular_Season.csv' créé avec succès! (30 équipes NBA)
# [54/58] 2022-23 - Playoffs
# Récupération des statistiques des équipes pour la saison 2022-23...
#   32 équipe(s) non-NBA filtrée(s) (WNBA/G-League)
#
# Fichier './data/2022-23/Playoffs/nba_teams_stats_2022-23_Playoffs.csv' créé avec succès! (16 équipes NBA)
# [55/58] 2023-24 - Regular Season
# Récupération des statistiques des équipes pour la saison 2023-24...
#   43 équipe(s) non-NBA filtrée(s) (WNBA/G-League)
#
# Fichier './data/2023-24/Regular_Season/nba_teams_stats_2023-24_Regular_Season.csv' créé avec succès! (30 équipes NBA)
# [56/58] 2023-24 - Playoffs
# Récupération des statistiques des équipes pour la saison 2023-24...
#   20 équipe(s) non-NBA filtrée(s) (WNBA/G-League)
#
# Fichier './data/2023-24/Playoffs/nba_teams_stats_2023-24_Playoffs.csv' créé avec succès! (16 équipes NBA)
# [57/58] 2024-25 - Regular Season
# Récupération des statistiques des équipes pour la saison 2024-25...
#   46 équipe(s) non-NBA filtrée(s) (WNBA/G-League)
#
# Fichier './data/2024-25/Regular_Season/nba_teams_stats_2024-25_Regular_Season.csv' créé avec succès! (30 équipes NBA)
# [58/58] 2024-25 - Playoffs
# Récupération des statistiques des équipes pour la saison 2024-25...
#   20 équipe(s) non-NBA filtrée(s) (WNBA/G-League)
#
# Fichier './data/2024-25/Playoffs/nba_teams_stats_2024-25_Playoffs.csv' créé avec succès! (16 équipes NBA)
#
# ============================================================
# Récupération terminée!
# 58 fichiers créés sur 58 attendus
# ============================================================
# {'1996-97_Regular Season': {'path': './data/1996-97/Regular_Season/nba_teams_stats_1996-97_Regular_Season.csv',
#   'teams_count': 29},
#  '1996-97_Playoffs': {'path': './data/1996-97/Playoffs/nba_teams_stats_1996-97_Playoffs.csv',
#   'teams_count': 16},
#  '1997-98_Regular Season': {'path': './data/1997-98/Regular_Season/nba_teams_stats_1997-98_Regular_Season.csv',
#   'teams_count': 29},
#  '1997-98_Playoffs': {'path': './data/1997-98/Playoffs/nba_teams_stats_1997-98_Playoffs.csv',
#   'teams_count': 16},
#  '1998-99_Regular Season': {'path': './data/1998-99/Regular_Season/nba_teams_stats_1998-99_Regular_Season.csv',
#   'teams_count': 29},
#  '1998-99_Playoffs': {'path': './data/1998-99/Playoffs/nba_teams_stats_1998-99_Playoffs.csv',
#   'teams_count': 16},
#  '1999-00_Regular Season': {'path': './data/1999-00/Regular_Season/nba_teams_stats_1999-00_Regular_Season.csv',
#   'teams_count': 29},
#  '1999-00_Playoffs': {'path': './data/1999-00/Playoffs/nba_teams_stats_1999-00_Playoffs.csv',
#   'teams_count': 16},
#  '2000-01_Regular Season': {'path': './data/2000-01/Regular_Season/nba_teams_stats_2000-01_Regular_Season.csv',
#   'teams_count': 29},
#  '2000-01_Playoffs': {'path': './data/2000-01/Playoffs/nba_teams_stats_2000-01_Playoffs.csv',
#   'teams_count': 16},
#  '2001-02_Regular Season': {'path': './data/2001-02/Regular_Season/nba_teams_stats_2001-02_Regular_Season.csv',
#   'teams_count': 29},
#  '2001-02_Playoffs': {'path': './data/2001-02/Playoffs/nba_teams_stats_2001-02_Playoffs.csv',
#   'teams_count': 16},
#  '2002-03_Regular Season': {'path': './data/2002-03/Regular_Season/nba_teams_stats_2002-03_Regular_Season.csv',
#   'teams_count': 29},
#  '2002-03_Playoffs': {'path': './data/2002-03/Playoffs/nba_teams_stats_2002-03_Playoffs.csv',
#   'teams_count': 16},
#  '2003-04_Regular Season': {'path': './data/2003-04/Regular_Season/nba_teams_stats_2003-04_Regular_Season.csv',
#   'teams_count': 29},
#  '2003-04_Playoffs': {'path': './data/2003-04/Playoffs/nba_teams_stats_2003-04_Playoffs.csv',
#   'teams_count': 16},
#  '2004-05_Regular Season': {'path': './data/2004-05/Regular_Season/nba_teams_stats_2004-05_Regular_Season.csv',
#   'teams_count': 30},
#  '2004-05_Playoffs': {'path': './data/2004-05/Playoffs/nba_teams_stats_2004-05_Playoffs.csv',
#   'teams_count': 16},
#  '2005-06_Regular Season': {'path': './data/2005-06/Regular_Season/nba_teams_stats_2005-06_Regular_Season.csv',
#   'teams_count': 30},
#  '2005-06_Playoffs': {'path': './data/2005-06/Playoffs/nba_teams_stats_2005-06_Playoffs.csv',
#   'teams_count': 16},
#  '2006-07_Regular Season': {'path': './data/2006-07/Regular_Season/nba_teams_stats_2006-07_Regular_Season.csv',
#   'teams_count': 30},
#  '2006-07_Playoffs': {'path': './data/2006-07/Playoffs/nba_teams_stats_2006-07_Playoffs.csv',
#   'teams_count': 16},
#  '2007-08_Regular Season': {'path': './data/2007-08/Regular_Season/nba_teams_stats_2007-08_Regular_Season.csv',
#   'teams_count': 30},
#  '2007-08_Playoffs': {'path': './data/2007-08/Playoffs/nba_teams_stats_2007-08_Playoffs.csv',
#   'teams_count': 16},
#  '2008-09_Regular Season': {'path': './data/2008-09/Regular_Season/nba_teams_stats_2008-09_Regular_Season.csv',
#   'teams_count': 30},
#  '2008-09_Playoffs': {'path': './data/2008-09/Playoffs/nba_teams_stats_2008-09_Playoffs.csv',
#   'teams_count': 16},
#  '2009-10_Regular Season': {'path': './data/2009-10/Regular_Season/nba_teams_stats_2009-10_Regular_Season.csv',
#   'teams_count': 30},
#  '2009-10_Playoffs': {'path': './data/2009-10/Playoffs/nba_teams_stats_2009-10_Playoffs.csv',
#   'teams_count': 16},
#  '2010-11_Regular Season': {'path': './data/2010-11/Regular_Season/nba_teams_stats_2010-11_Regular_Season.csv',
#   'teams_count': 30},
#  '2010-11_Playoffs': {'path': './data/2010-11/Playoffs/nba_teams_stats_2010-11_Playoffs.csv',
#   'teams_count': 16},
#  '2011-12_Regular Season': {'path': './data/2011-12/Regular_Season/nba_teams_stats_2011-12_Regular_Season.csv',
#   'teams_count': 30},
#  '2011-12_Playoffs': {'path': './data/2011-12/Playoffs/nba_teams_stats_2011-12_Playoffs.csv',
#   'teams_count': 16},
#  '2012-13_Regular Season': {'path': './data/2012-13/Regular_Season/nba_teams_stats_2012-13_Regular_Season.csv',
#   'teams_count': 30},
#  '2012-13_Playoffs': {'path': './data/2012-13/Playoffs/nba_teams_stats_2012-13_Playoffs.csv',
#   'teams_count': 16},
#  '2013-14_Regular Season': {'path': './data/2013-14/Regular_Season/nba_teams_stats_2013-14_Regular_Season.csv',
#   'teams_count': 30},
#  '2013-14_Playoffs': {'path': './data/2013-14/Playoffs/nba_teams_stats_2013-14_Playoffs.csv',
#   'teams_count': 16},
#  '2014-15_Regular Season': {'path': './data/2014-15/Regular_Season/nba_teams_stats_2014-15_Regular_Season.csv',
#   'teams_count': 30},
#  '2014-15_Playoffs': {'path': './data/2014-15/Playoffs/nba_teams_stats_2014-15_Playoffs.csv',
#   'teams_count': 16},
#  '2015-16_Regular Season': {'path': './data/2015-16/Regular_Season/nba_teams_stats_2015-16_Regular_Season.csv',
#   'teams_count': 30},
#  '2015-16_Playoffs': {'path': './data/2015-16/Playoffs/nba_teams_stats_2015-16_Playoffs.csv',
#   'teams_count': 16},
#  '2016-17_Regular Season': {'path': './data/2016-17/Regular_Season/nba_teams_stats_2016-17_Regular_Season.csv',
#   'teams_count': 30},
#  '2016-17_Playoffs': {'path': './data/2016-17/Playoffs/nba_teams_stats_2016-17_Playoffs.csv',
#   'teams_count': 16},
#  '2017-18_Regular Season': {'path': './data/2017-18/Regular_Season/nba_teams_stats_2017-18_Regular_Season.csv',
#   'teams_count': 30},
#  '2017-18_Playoffs': {'path': './data/2017-18/Playoffs/nba_teams_stats_2017-18_Playoffs.csv',
#   'teams_count': 16},
#  '2018-19_Regular Season': {'path': './data/2018-19/Regular_Season/nba_teams_stats_2018-19_Regular_Season.csv',
#   'teams_count': 30},
#  '2018-19_Playoffs': {'path': './data/2018-19/Playoffs/nba_teams_stats_2018-19_Playoffs.csv',
#   'teams_count': 16},
#  '2019-20_Regular Season': {'path': './data/2019-20/Regular_Season/nba_teams_stats_2019-20_Regular_Season.csv',
#   'teams_count': 30},
#  '2019-20_Playoffs': {'path': './data/2019-20/Playoffs/nba_teams_stats_2019-20_Playoffs.csv',
#   'teams_count': 16},
#  '2020-21_Regular Season': {'path': './data/2020-21/Regular_Season/nba_teams_stats_2020-21_Regular_Season.csv',
#   'teams_count': 30},
#  '2020-21_Playoffs': {'path': './data/2020-21/Playoffs/nba_teams_stats_2020-21_Playoffs.csv',
#   'teams_count': 16},
#  '2021-22_Regular Season': {'path': './data/2021-22/Regular_Season/nba_teams_stats_2021-22_Regular_Season.csv',
#   'teams_count': 30},
#  '2021-22_Playoffs': {'path': './data/2021-22/Playoffs/nba_teams_stats_2021-22_Playoffs.csv',
#   'teams_count': 16},
#  '2022-23_Regular Season': {'path': './data/2022-23/Regular_Season/nba_teams_stats_2022-23_Regular_Season.csv',
#   'teams_count': 30},
#  '2022-23_Playoffs': {'path': './data/2022-23/Playoffs/nba_teams_stats_2022-23_Playoffs.csv',
#   'teams_count': 16},
#  '2023-24_Regular Season': {'path': './data/2023-24/Regular_Season/nba_teams_stats_2023-24_Regular_Season.csv',
#   'teams_count': 30},
#  '2023-24_Playoffs': {'path': './data/2023-24/Playoffs/nba_teams_stats_2023-24_Playoffs.csv',
#   'teams_count': 16},
#  '2024-25_Regular Season': {'path': './data/2024-25/Regular_Season/nba_teams_stats_2024-25_Regular_Season.csv',
#   'teams_count': 30},
#  '2024-25_Playoffs': {'path': './data/2024-25/Playoffs/nba_teams_stats_2024-25_Playoffs.csv',
#   'teams_count': 16}}

# %%
export_all_salaries()
# Out:
# ============================================================
#  Récupération des salaires NBA
# De la saison 1999-00 à 2024-25
# Total: 26 saisons
# ============================================================
#
# [1/26] Saison 1999-00
#   Récupération des salaires depuis ESPN pour 1999-2000...
#     Page 1...  40 joueurs
#     Page 2...  40 joueurs
#     Page 3...  40 joueurs
#     Page 4...  37 joueurs
#     Page 5...  Fin (aucune ligne)
#    157 salaires récupérés au total - Fichier créé!
# [2/26] Saison 2000-01
#   Récupération des salaires depuis ESPN pour 2000-2001...
#     Page 1...  40 joueurs
#     Page 2...  40 joueurs
#     Page 3...  40 joueurs
#     Page 4...  40 joueurs
#     Page 5...  40 joueurs
#     Page 6...  40 joueurs
#     Page 7...  40 joueurs
#     Page 8...  40 joueurs
#     Page 9...  40 joueurs
#     Page 10...  14 joueurs
#     Page 11...  Fin (aucune ligne)
#    374 salaires récupérés au total - Fichier créé!
# [3/26] Saison 2001-02
#   Récupération des salaires depuis ESPN pour 2001-2002...
#     Page 1...  40 joueurs
#     Page 2...  40 joueurs
#     Page 3...  40 joueurs
#     Page 4...  40 joueurs
#     Page 5...  40 joueurs
#     Page 6...  40 joueurs
#     Page 7...  40 joueurs
#     Page 8...  40 joueurs
#     Page 9...  40 joueurs
#     Page 10...  40 joueurs
#     Page 11...  16 joueurs
#     Page 12...  Fin (aucune ligne)
#    416 salaires récupérés au total - Fichier créé!
# [4/26] Saison 2002-03
#   Récupération des salaires depuis ESPN pour 2002-2003...
#     Page 1...  40 joueurs
#     Page 2...  40 joueurs
#     Page 3...  40 joueurs
#     Page 4...  40 joueurs
#     Page 5...  40 joueurs
#     Page 6...  40 joueurs
#     Page 7...  40 joueurs
#     Page 8...  Fin (aucune ligne)
#    280 salaires récupérés au total - Fichier créé!
# [5/26] Saison 2003-04
#   Récupération des salaires depuis ESPN pour 2003-2004...
#     Page 1...  40 joueurs
#     Page 2...  40 joueurs
#     Page 3...  40 joueurs
#     Page 4...  40 joueurs
#     Page 5...  20 joueurs
#     Page 6...  Fin (aucune ligne)
#    180 salaires récupérés au total - Fichier créé!
# [6/26] Saison 2004-05
#   Récupération des salaires depuis ESPN pour 2004-2005...
#     Page 1...  40 joueurs
#     Page 2...  40 joueurs
#     Page 3...  40 joueurs
#     Page 4...  Fin (aucune ligne)
#    120 salaires récupérés au total - Fichier créé!
# [7/26] Saison 2005-06
#   Récupération des salaires depuis ESPN pour 2005-2006...
#     Page 1...  40 joueurs
#     Page 2...  40 joueurs
#     Page 3...  40 joueurs
#     Page 4...  40 joueurs
#     Page 5...  40 joueurs
#     Page 6...  40 joueurs
#     Page 7...  40 joueurs
#     Page 8...  40 joueurs
#     Page 9...  40 joueurs
#     Page 10...  40 joueurs
#     Page 11...  36 joueurs
#     Page 12...  Fin (aucune ligne)
#    436 salaires récupérés au total - Fichier créé!
# [8/26] Saison 2006-07
#   Récupération des salaires depuis ESPN pour 2006-2007...
#     Page 1...  40 joueurs
#     Page 2...  40 joueurs
#     Page 3...  40 joueurs
#     Page 4...  40 joueurs
#     Page 5...  40 joueurs
#     Page 6...  40 joueurs
#     Page 7...  40 joueurs
#     Page 8...  40 joueurs
#     Page 9...  40 joueurs
#     Page 10...  40 joueurs
#     Page 11...  40 joueurs
#     Page 12...  29 joueurs
#     Page 13...  Fin (aucune ligne)
#    469 salaires récupérés au total - Fichier créé!
# [9/26] Saison 2007-08
#   Récupération des salaires depuis ESPN pour 2007-2008...
#     Page 1...  40 joueurs
#     Page 2...  40 joueurs
#     Page 3...  40 joueurs
#     Page 4...  40 joueurs
#     Page 5...  40 joueurs
#     Page 6...  40 joueurs
#     Page 7...  40 joueurs
#     Page 8...  40 joueurs
#     Page 9...  40 joueurs
#     Page 10...  40 joueurs
#     Page 11...  40 joueurs
#     Page 12...  40 joueurs
#     Page 13...  8 joueurs
#     Page 14...  Fin (aucune ligne)
#    488 salaires récupérés au total - Fichier créé!
# [10/26] Saison 2008-09
#   Récupération des salaires depuis ESPN pour 2008-2009...
#     Page 1...  40 joueurs
#     Page 2...  40 joueurs
#     Page 3...  40 joueurs
#     Page 4...  40 joueurs
#     Page 5...  40 joueurs
#     Page 6...  40 joueurs
#     Page 7...  40 joueurs
#     Page 8...  40 joueurs
#     Page 9...  40 joueurs
#     Page 10...  40 joueurs
#     Page 11...  40 joueurs
#     Page 12...  40 joueurs
#     Page 13...  1 joueurs
#     Page 14...  Fin (aucune ligne)
#    481 salaires récupérés au total - Fichier créé!
# [11/26] Saison 2009-10
#   Récupération des salaires depuis ESPN pour 2009-2010...
#     Page 1...  40 joueurs
#     Page 2...  40 joueurs
#     Page 3...  40 joueurs
#     Page 4...  40 joueurs
#     Page 5...  40 joueurs
#     Page 6...  40 joueurs
#     Page 7...  40 joueurs
#     Page 8...  40 joueurs
#     Page 9...  40 joueurs
#     Page 10...  40 joueurs
#     Page 11...  40 joueurs
#     Page 12...  38 joueurs
#     Page 13...  Fin (aucune ligne)
#    478 salaires récupérés au total - Fichier créé!
# [12/26] Saison 2010-11
#   Récupération des salaires depuis ESPN pour 2010-2011...
#     Page 1...  40 joueurs
#     Page 2...  40 joueurs
#     Page 3...  40 joueurs
#     Page 4...  40 joueurs
#     Page 5...  40 joueurs
#     Page 6...  40 joueurs
#     Page 7...  40 joueurs
#     Page 8...  40 joueurs
#     Page 9...  40 joueurs
#     Page 10...  40 joueurs
#     Page 11...  40 joueurs
#     Page 12...  40 joueurs
#     Page 13...  40 joueurs
#     Page 14...  17 joueurs
#     Page 15...  Fin (aucune ligne)
#    537 salaires récupérés au total - Fichier créé!
# [13/26] Saison 2011-12
#   Récupération des salaires depuis ESPN pour 2011-2012...
#     Page 1...  40 joueurs
#     Page 2...  40 joueurs
#     Page 3...  40 joueurs
#     Page 4...  40 joueurs
#     Page 5...  40 joueurs
#     Page 6...  40 joueurs
#     Page 7...  40 joueurs
#     Page 8...  40 joueurs
#     Page 9...  40 joueurs
#     Page 10...  40 joueurs
#     Page 11...  40 joueurs
#     Page 12...  40 joueurs
#     Page 13...  40 joueurs
#     Page 14...  40 joueurs
#     Page 15...  40 joueurs
#     Page 16...  13 joueurs
#     Page 17...  Fin (aucune ligne)
#    613 salaires récupérés au total - Fichier créé!
# [14/26] Saison 2012-13
#   Récupération des salaires depuis ESPN pour 2012-2013...
#     Page 1...  40 joueurs
#     Page 2...  40 joueurs
#     Page 3...  40 joueurs
#     Page 4...  40 joueurs
#     Page 5...  40 joueurs
#     Page 6...  40 joueurs
#     Page 7...  40 joueurs
#     Page 8...  40 joueurs
#     Page 9...  40 joueurs
#     Page 10...  40 joueurs
#     Page 11...  40 joueurs
#     Page 12...  40 joueurs
#     Page 13...  40 joueurs
#     Page 14...  40 joueurs
#     Page 15...  40 joueurs
#     Page 16...  40 joueurs
#     Page 17...  40 joueurs
#     Page 18...  8 joueurs
#     Page 19...  Fin (aucune ligne)
#    688 salaires récupérés au total - Fichier créé!
# [15/26] Saison 2013-14
#   Récupération des salaires depuis ESPN pour 2013-2014...
#     Page 1...  40 joueurs
#     Page 2...  40 joueurs
#     Page 3...  40 joueurs
#     Page 4...  40 joueurs
#     Page 5...  40 joueurs
#     Page 6...  40 joueurs
#     Page 7...  40 joueurs
#     Page 8...  40 joueurs
#     Page 9...  40 joueurs
#     Page 10...  40 joueurs
#     Page 11...  26 joueurs
#     Page 12...  Fin (aucune ligne)
#    426 salaires récupérés au total - Fichier créé!
# [16/26] Saison 2014-15
#   Récupération des salaires depuis ESPN pour 2014-2015...
#     Page 1...  40 joueurs
#     Page 2...  40 joueurs
#     Page 3...  40 joueurs
#     Page 4...  40 joueurs
#     Page 5...  40 joueurs
#     Page 6...  40 joueurs
#     Page 7...  40 joueurs
#     Page 8...  40 joueurs
#     Page 9...  40 joueurs
#     Page 10...  40 joueurs
#     Page 11...  40 joueurs
#     Page 12...  40 joueurs
#     Page 13...  35 joueurs
#     Page 14...  Fin (aucune ligne)
#    515 salaires récupérés au total - Fichier créé!
# [17/26] Saison 2015-16
#   Récupération des salaires depuis ESPN pour 2015-2016...
#     Page 1...  40 joueurs
#     Page 2...  40 joueurs
#     Page 3...  40 joueurs
#     Page 4...  40 joueurs
#     Page 5...  40 joueurs
#     Page 6...  40 joueurs
#     Page 7...  40 joueurs
#     Page 8...  40 joueurs
#     Page 9...  40 joueurs
#     Page 10...  40 joueurs
#     Page 11...  40 joueurs
#     Page 12...  40 joueurs
#     Page 13...  28 joueurs
#     Page 14...  Fin (aucune ligne)
#    508 salaires récupérés au total - Fichier créé!
# [18/26] Saison 2016-17
#   Récupération des salaires depuis ESPN pour 2016-2017...
#     Page 1...  40 joueurs
#     Page 2...  40 joueurs
#     Page 3...  40 joueurs
#     Page 4...  40 joueurs
#     Page 5...  40 joueurs
#     Page 6...  40 joueurs
#     Page 7...  40 joueurs
#     Page 8...  40 joueurs
#     Page 9...  40 joueurs
#     Page 10...  40 joueurs
#     Page 11...  40 joueurs
#     Page 12...  40 joueurs
#     Page 13...  40 joueurs
#     Page 14...  40 joueurs
#     Page 15...  17 joueurs
#     Page 16...  Fin (aucune ligne)
#    577 salaires récupérés au total - Fichier créé!
# [19/26] Saison 2017-18
#   Récupération des salaires depuis ESPN pour 2017-2018...
#     Page 1...  40 joueurs
#     Page 2...  40 joueurs
#     Page 3...  40 joueurs
#     Page 4...  40 joueurs
#     Page 5...  40 joueurs
#     Page 6...  40 joueurs
#     Page 7...  40 joueurs
#     Page 8...  40 joueurs
#     Page 9...  40 joueurs
#     Page 10...  40 joueurs
#     Page 11...  40 joueurs
#     Page 12...  40 joueurs
#     Page 13...  40 joueurs
#     Page 14...  40 joueurs
#     Page 15...  24 joueurs
#     Page 16...  Fin (aucune ligne)
#    584 salaires récupérés au total - Fichier créé!
# [20/26] Saison 2018-19
#   Récupération des salaires depuis ESPN pour 2018-2019...
#     Page 1...  40 joueurs
#     Page 2...  40 joueurs
#     Page 3...  40 joueurs
#     Page 4...  40 joueurs
#     Page 5...  40 joueurs
#     Page 6...  40 joueurs
#     Page 7...  40 joueurs
#     Page 8...  40 joueurs
#     Page 9...  40 joueurs
#     Page 10...  40 joueurs
#     Page 11...  40 joueurs
#     Page 12...  40 joueurs
#     Page 13...  13 joueurs
#     Page 14...  Fin (aucune ligne)
#    493 salaires récupérés au total - Fichier créé!
# [21/26] Saison 2019-20
#   Récupération des salaires depuis ESPN pour 2019-2020...
#     Page 1...  40 joueurs
#     Page 2...  40 joueurs
#     Page 3...  40 joueurs
#     Page 4...  40 joueurs
#     Page 5...  40 joueurs
#     Page 6...  40 joueurs
#     Page 7...  40 joueurs
#     Page 8...  40 joueurs
#     Page 9...  40 joueurs
#     Page 10...  40 joueurs
#     Page 11...  40 joueurs
#     Page 12...  40 joueurs
#     Page 13...  40 joueurs
#     Page 14...  Fin (aucune ligne)
#    520 salaires récupérés au total - Fichier créé!
# [22/26] Saison 2020-21
#   Récupération des salaires depuis ESPN pour 2020-2021...
#     Page 1...  40 joueurs
#     Page 2...  40 joueurs
#     Page 3...  40 joueurs
#     Page 4...  40 joueurs
#     Page 5...  40 joueurs
#     Page 6...  40 joueurs
#     Page 7...  40 joueurs
#     Page 8...  40 joueurs
#     Page 9...  40 joueurs
#     Page 10...  40 joueurs
#     Page 11...  40 joueurs
#     Page 12...  40 joueurs
#     Page 13...  40 joueurs
#     Page 14...  36 joueurs
#     Page 15...  Fin (aucune ligne)
#    556 salaires récupérés au total - Fichier créé!
# [23/26] Saison 2021-22
#   Récupération des salaires depuis ESPN pour 2021-2022...
#     Page 1...  40 joueurs
#     Page 2...  40 joueurs
#     Page 3...  40 joueurs
#     Page 4...  40 joueurs
#     Page 5...  40 joueurs
#     Page 6...  40 joueurs
#     Page 7...  40 joueurs
#     Page 8...  40 joueurs
#     Page 9...  40 joueurs
#     Page 10...  40 joueurs
#     Page 11...  40 joueurs
#     Page 12...  40 joueurs
#     Page 13...  17 joueurs
#     Page 14...  Fin (aucune ligne)
#    497 salaires récupérés au total - Fichier créé!
# [24/26] Saison 2022-23
#   Récupération des salaires depuis ESPN pour 2022-2023...
#     Page 1...  40 joueurs
#     Page 2...  40 joueurs
#     Page 3...  40 joueurs
#     Page 4...  40 joueurs
#     Page 5...  40 joueurs
#     Page 6...  40 joueurs
#     Page 7...  40 joueurs
#     Page 8...  40 joueurs
#     Page 9...  40 joueurs
#     Page 10...  40 joueurs
#     Page 11...  40 joueurs
#     Page 12...  40 joueurs
#     Page 13...  40 joueurs
#     Page 14...  9 joueurs
#     Page 15...  Fin (aucune ligne)
#    529 salaires récupérés au total - Fichier créé!
# [25/26] Saison 2023-24
#   Récupération des salaires depuis ESPN pour 2023-2024...
#     Page 1...  40 joueurs
#     Page 2...  40 joueurs
#     Page 3...  40 joueurs
#     Page 4...  40 joueurs
#     Page 5...  40 joueurs
#     Page 6...  40 joueurs
#     Page 7...  40 joueurs
#     Page 8...  40 joueurs
#     Page 9...  40 joueurs
#     Page 10...  40 joueurs
#     Page 11...  40 joueurs
#     Page 12...  35 joueurs
#     Page 13...  Fin (aucune ligne)
#    475 salaires récupérés au total - Fichier créé!
# [26/26] Saison 2024-25
#   Récupération des salaires depuis ESPN pour 2024-2025...
#     Page 1...  40 joueurs
#     Page 2...  40 joueurs
#     Page 3...  40 joueurs
#     Page 4...  40 joueurs
#     Page 5...  40 joueurs
#     Page 6...  40 joueurs
#     Page 7...  40 joueurs
#     Page 8...  40 joueurs
#     Page 9...  40 joueurs
#     Page 10...  40 joueurs
#     Page 11...  40 joueurs
#     Page 12...  40 joueurs
#     Page 13...  11 joueurs
#     Page 14...  Fin (aucune ligne)
#    491 salaires récupérés au total - Fichier créé!
# ============================================================
#  Récupération terminée!
#  26 fichiers créés sur 26 attendus
# ============================================================
# {'1999-00': {'path': './data/1999-00/Salaries/nba_salaries_1999-00.csv',
#   'players_count': 157},
#  '2000-01': {'path': './data/2000-01/Salaries/nba_salaries_2000-01.csv',
#   'players_count': 374},
#  '2001-02': {'path': './data/2001-02/Salaries/nba_salaries_2001-02.csv',
#   'players_count': 416},
#  '2002-03': {'path': './data/2002-03/Salaries/nba_salaries_2002-03.csv',
#   'players_count': 280},
#  '2003-04': {'path': './data/2003-04/Salaries/nba_salaries_2003-04.csv',
#   'players_count': 180},
#  '2004-05': {'path': './data/2004-05/Salaries/nba_salaries_2004-05.csv',
#   'players_count': 120},
#  '2005-06': {'path': './data/2005-06/Salaries/nba_salaries_2005-06.csv',
#   'players_count': 436},
#  '2006-07': {'path': './data/2006-07/Salaries/nba_salaries_2006-07.csv',
#   'players_count': 469},
#  '2007-08': {'path': './data/2007-08/Salaries/nba_salaries_2007-08.csv',
#   'players_count': 488},
#  '2008-09': {'path': './data/2008-09/Salaries/nba_salaries_2008-09.csv',
#   'players_count': 481},
#  '2009-10': {'path': './data/2009-10/Salaries/nba_salaries_2009-10.csv',
#   'players_count': 478},
#  '2010-11': {'path': './data/2010-11/Salaries/nba_salaries_2010-11.csv',
#   'players_count': 537},
#  '2011-12': {'path': './data/2011-12/Salaries/nba_salaries_2011-12.csv',
#   'players_count': 613},
#  '2012-13': {'path': './data/2012-13/Salaries/nba_salaries_2012-13.csv',
#   'players_count': 688},
#  '2013-14': {'path': './data/2013-14/Salaries/nba_salaries_2013-14.csv',
#   'players_count': 426},
#  '2014-15': {'path': './data/2014-15/Salaries/nba_salaries_2014-15.csv',
#   'players_count': 515},
#  '2015-16': {'path': './data/2015-16/Salaries/nba_salaries_2015-16.csv',
#   'players_count': 508},
#  '2016-17': {'path': './data/2016-17/Salaries/nba_salaries_2016-17.csv',
#   'players_count': 577},
#  '2017-18': {'path': './data/2017-18/Salaries/nba_salaries_2017-18.csv',
#   'players_count': 584},
#  '2018-19': {'path': './data/2018-19/Salaries/nba_salaries_2018-19.csv',
#   'players_count': 493},
#  '2019-20': {'path': './data/2019-20/Salaries/nba_salaries_2019-20.csv',
#   'players_count': 520},
#  '2020-21': {'path': './data/2020-21/Salaries/nba_salaries_2020-21.csv',
#   'players_count': 556},
#  '2021-22': {'path': './data/2021-22/Salaries/nba_salaries_2021-22.csv',
#   'players_count': 497},
#  '2022-23': {'path': './data/2022-23/Salaries/nba_salaries_2022-23.csv',
#   'players_count': 529},
#  '2023-24': {'path': './data/2023-24/Salaries/nba_salaries_2023-24.csv',
#   'players_count': 475},
#  '2024-25': {'path': './data/2024-25/Salaries/nba_salaries_2024-25.csv',
#   'players_count': 491}}

# %%
scrape_mvp_data()
# Out:
#  Récupération de l'historique des MVP NBA avec Selenium...
#   URL: https://www.basketball-reference.com/awards/mvp.html
#  Initialisation du navigateur
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 scrape_mvp_data()
#
# File ~/work/build_nba_bdd.py:467, in scrape_mvp_data(filename)
#     464 print(" Initialisation du navigateur")
#     466 # Créer le driver
# --> 467 driver = webdriver.Chrome(options=chrome_options)
#     469 # Masquer l'automation
#     470 driver.execute_script("Object.defineProperty(navigator, 'webdriver', {get: () => undefined})")
#
# File /opt/python/lib/python3.13/site-packages/selenium/webdriver/chrome/webdriver.py:47, in WebDriver.__init__(self, options, service, keep_alive)
#      44 service = service if service else Service()
#      45 options = options if options else Options()
# ---> 47 super().__init__(
#      48     browser_name=DesiredCapabilities.CHROME["browserName"],
#      49     vendor_prefix="goog",
#      50     options=options,
#      51     service=service,
#      52     keep_alive=keep_alive,
#      53 )
#
# File /opt/python/lib/python3.13/site-packages/selenium/webdriver/chromium/webdriver.py:55, in ChromiumDriver.__init__(self, browser_name, vendor_prefix, options, service, keep_alive)
#      52 options = options if options else ChromiumOptions()
#      54 finder = DriverFinder(self.service, options)
# ---> 55 if finder.get_browser_path():
#      56     options.binary_location = finder.get_browser_path()
#      57     options.browser_version = None
#
# File /opt/python/lib/python3.13/site-packages/selenium/webdriver/common/driver_finder.py:48, in DriverFinder.get_browser_path(self)
#      47 def get_browser_path(self) -> str:
# ---> 48     return self._binary_paths()["browser_path"]
#
# File /opt/python/lib/python3.13/site-packages/selenium/webdriver/common/driver_finder.py:68, in DriverFinder._binary_paths(self)
#      66     self._paths["driver_path"] = path
#      67 else:
# ---> 68     output = SeleniumManager().binary_paths(self._to_args())
#      69     if Path(output["driver_path"]).is_file():
#      70         self._paths["driver_path"] = output["driver_path"]
#
# File /opt/python/lib/python3.13/site-packages/selenium/webdriver/common/selenium_manager.py:56, in SeleniumManager.binary_paths(self, args)
#      53 args.append("--output")
#      54 args.append("json")
# ---> 56 return self._run(args)
#
# File /opt/python/lib/python3.13/site-packages/selenium/webdriver/common/selenium_manager.py:124, in SeleniumManager._run(args)
#     122     completed_proc = subprocess.run(args, capture_output=True, creationflags=subprocess.CREATE_NO_WINDOW)
#     123 else:
# --> 124     completed_proc = subprocess.run(args, capture_output=True)
#     125 stdout = completed_proc.stdout.decode("utf-8").rstrip("\n")
#     126 stderr = completed_proc.stderr.decode("utf-8").rstrip("\n")
#
# File /opt/python/lib/python3.13/subprocess.py:556, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     554 with Popen(*popenargs, **kwargs) as process:
#     555     try:
# --> 556         stdout, stderr = process.communicate(input, timeout=timeout)
#     557     except TimeoutExpired as exc:
#     558         process.kill()
#
# File /opt/python/lib/python3.13/subprocess.py:1222, in Popen.communicate(self, input, timeout)
#    1219     endtime = None
#    1221 try:
# -> 1222     stdout, stderr = self._communicate(input, endtime, timeout)
#    1223 except KeyboardInterrupt:
#    1224     # https://bugs.python.org/issue25942
#    1225     # See the detailed comment in .wait().
#    1226     if timeout is not None:
#
# File /opt/python/lib/python3.13/subprocess.py:2128, in Popen._communicate(self, input, endtime, orig_timeout)
#    2121     self._check_timeout(endtime, orig_timeout,
#    2122                         stdout, stderr,
#    2123                         skip_check_and_raise=True)
#    2124     raise RuntimeError(  # Impossible :)
#    2125         '_check_timeout(..., skip_check_and_raise=True) '
#    2126         'failed to raise TimeoutExpired.')
# -> 2128 ready = selector.select(timeout)
#    2129 self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2131 # XXX Rewrite these to use non-blocking I/O on the file
#    2132 # objects; they are no longer using C stdio!
#
# File /opt/python/lib/python3.13/selectors.py:398, in _PollLikeSelector.select(self, timeout)
#     396 ready = []
#     397 try:
# --> 398     fd_event_list = self._selector.poll(timeout)
#     399 except InterruptedError:
#     400     return ready
#
# KeyboardInterrupt:

# %%
merge_data()
# Out:
# ============================================================
#  Fusion des données joueurs + salaires
#  De 1999-00 à 2024-25
#  Ajustement des salaires à l'inflation de 2024
# ============================================================
#
# [1/26] Saison 1999-00...  154 joueurs fusionnés
# [2/26] Saison 2000-01...  366 joueurs fusionnés
# [3/26] Saison 2001-02...  411 joueurs fusionnés
# [4/26] Saison 2002-03...  278 joueurs fusionnés
# [5/26] Saison 2003-04...  177 joueurs fusionnés
# [6/26] Saison 2004-05...  118 joueurs fusionnés
# [7/26] Saison 2005-06...  424 joueurs fusionnés
# [8/26] Saison 2006-07...  434 joueurs fusionnés
# [9/26] Saison 2007-08...  433 joueurs fusionnés
# [10/26] Saison 2008-09...  429 joueurs fusionnés
# [11/26] Saison 2009-10...  428 joueurs fusionnés
# [12/26] Saison 2010-11...  436 joueurs fusionnés
# [13/26] Saison 2011-12...  460 joueurs fusionnés
# [14/26] Saison 2012-13...  439 joueurs fusionnés
# [15/26] Saison 2013-14...  410 joueurs fusionnés
# [16/26] Saison 2014-15...  460 joueurs fusionnés
# [17/26] Saison 2015-16...  441 joueurs fusionnés
# [18/26] Saison 2016-17...  457 joueurs fusionnés
# [19/26] Saison 2017-18...  394 joueurs fusionnés
# [20/26] Saison 2018-19...  445 joueurs fusionnés
# [21/26] Saison 2019-20...  434 joueurs fusionnés
# [22/26] Saison 2020-21...  447 joueurs fusionnés
# [23/26] Saison 2021-22...  457 joueurs fusionnés
# [24/26] Saison 2022-23...  460 joueurs fusionnés
# [25/26] Saison 2023-24...  442 joueurs fusionnés
# [26/26] Saison 2024-25...  451 joueurs fusionnés
#
# ============================================================
#  Combinaison de toutes les saisons...
#   Fichier final créé: ./data/merged_data.csv
#  Total de lignes: 10285
#  Saisons fusionnées: 26/26
#  Colonnes: 78
# ============================================================
#        PLAYER_ID      PLAYER_NAME  NICKNAME     TEAM_ID TEAM_ABBREVIATION  \
# 0              3       Grant Long     Grant  1610612763               VAN
# 1              3       Grant Long     Grant  1610612763               VAN
# 2              3       Grant Long     Grant  1610612763               MEM
# 3             15  Eric Piatkowski      Eric  1610612746               LAC
# 4             15  Eric Piatkowski      Eric  1610612746               LAC
# ...          ...              ...       ...         ...               ...
# 10280    1642367   Jonathan Mogbo  Jonathan  1610612761               TOR
# 10281    1642377     Jaylen Wells    Jaylen  1610612763               MEM
# 10282    1642382  Branden Carlson   Branden  1610612760               OKC
# 10283    1642403      Isaac Jones     Isaac  1610612758               SAC
# 10284    1642419   Jamison Battle   Jamison  1610612761               TOR
#
#         AGE  GP   W   L  W_PCT  ...  Position                   Team   Salary  \
# 0      34.0  42  13  29  0.310  ...         F    Vancouver Grizzlies  2000000
# 1      35.0  66  19  47  0.288  ...         F    Vancouver Grizzlies  2200000
# 2      36.0  66  18  48  0.273  ...         F      Memphis Grizzlies  2400000
# 3      29.0  75  13  62  0.173  ...        SG   Los Angeles Clippers  2000000
# 4      30.0  81  31  50  0.383  ...        SG   Los Angeles Clippers  3000000
# ...     ...  ..  ..  ..    ...  ...       ...                    ...      ...
# 10280  23.0  63  18  45  0.286  ...         F        Toronto Raptors  1862265
# 10281  21.0  79  47  32  0.595  ...         F      Memphis Grizzlies  1157153
# 10282  26.0  32  29   3  0.906  ...         C  Oklahoma City Thunder   990895
# 10283  24.0  40  19  21  0.475  ...         C       Sacramento Kings   152957
# 10284  24.0  59  21  38  0.356  ...         F        Toronto Raptors  1000000
#
#         Season  TEAM_W_PCT     Year  adjusted_salary  next_adjusted_salary  \
# 0      1999-00       0.268  1999-00          3880000             4136000.0
# 1      2000-01       0.280  2000-01          4136000             4392000.0
# 2      2001-02       0.280  2001-02          4392000                   NaN
# 3      1999-00       0.183  1999-00          3880000             5640000.0
# 4      2000-01       0.378  2000-01          5640000             5490000.0
# ...        ...         ...      ...              ...                   ...
# 10280  2024-25       0.368  2024-25          1918133                   NaN
# 10281  2024-25       0.593  2024-25          1191868                   NaN
# 10282  2024-25       0.789  2024-25          1020622                   NaN
# 10283  2024-25       0.483  2024-25           157546                   NaN
# 10284  2024-25       0.368  2024-25          1030000                   NaN
#
#        Changed_team  YOE
# 0               0.0    1
# 1               0.0    2
# 2               NaN    3
# 3               0.0    1
# 4               0.0    2
# ...             ...  ...
# 10280           NaN    1
# 10281           NaN    1
# 10282           NaN    1
# 10283           NaN    1
# 10284           NaN    1
#
# [10285 rows x 78 columns]

# %% [markdown]
# # Cohérence et prédiction des salaires NBA en fonction des performances sportives
#
# ## Problématique : Les salaires des joueurs NBA sont ils cohérent avec leurs performances sportives ? Les joueurs les mieux payés sont ils les plus efficaces statistiquement? Peut on prédire les salaires futures de ces joueurs ?
#
# On cherchera d’abord à savoir si les salaires de l’année T peuvent être justifiés par la performance sportive de cette même année. L’investissement de l’équipe sur un joueur a t-elle été justifié et cohérente ? Nous essaierons ensuite de prédire les salaires des joueurs pour une saison future en fonction des performance sportives passées et de quelques autres facteurs déterminents.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Charger la base de données fusionnée
df = pd.read_csv('./data/merged_data.csv')

print(f"Dataset chargé: {len(df)} lignes, {len(df.columns)} colonnes")
print(f"\nAperçu des colonnes:")
print(df.columns.tolist())
# Out:
# Dataset chargé: 10285 lignes, 78 colonnes
#
# Aperçu des colonnes:
# ['PLAYER_ID', 'PLAYER_NAME', 'NICKNAME', 'TEAM_ID', 'TEAM_ABBREVIATION', 'AGE', 'GP', 'W', 'L', 'W_PCT', 'MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'TOV', 'STL', 'BLK', 'BLKA', 'PF', 'PFD', 'PTS', 'PLUS_MINUS', 'NBA_FANTASY_PTS', 'DD2', 'TD3', 'WNBA_FANTASY_PTS', 'GP_RANK', 'W_RANK', 'L_RANK', 'W_PCT_RANK', 'MIN_RANK', 'FGM_RANK', 'FGA_RANK', 'FG_PCT_RANK', 'FG3M_RANK', 'FG3A_RANK', 'FG3_PCT_RANK', 'FTM_RANK', 'FTA_RANK', 'FT_PCT_RANK', 'OREB_RANK', 'DREB_RANK', 'REB_RANK', 'AST_RANK', 'TOV_RANK', 'STL_RANK', 'BLK_RANK', 'BLKA_RANK', 'PF_RANK', 'PFD_RANK', 'PTS_RANK', 'PLUS_MINUS_RANK', 'NBA_FANTASY_PTS_RANK', 'DD2_RANK', 'TD3_RANK', 'WNBA_FANTASY_PTS_RANK', 'TEAM_COUNT', 'Rank', 'Position', 'Team', 'Salary', 'Season', 'TEAM_W_PCT', 'Year', 'adjusted_salary', 'next_adjusted_salary', 'Changed_team', 'YOE']

# %%
# Afficher les premières lignes
print("\n Aperçu des données:\n")
print(df.head())

print("\n Informations sur les données: \n")
print(df.info())
# Out:
#  Aperçu des données:
#
#    PLAYER_ID      PLAYER_NAME NICKNAME     TEAM_ID TEAM_ABBREVIATION   AGE  \
# 0          3       Grant Long    Grant  1610612763               VAN  34.0
# 1          3       Grant Long    Grant  1610612763               VAN  35.0
# 2          3       Grant Long    Grant  1610612763               MEM  36.0
# 3         15  Eric Piatkowski     Eric  1610612746               LAC  29.0
# 4         15  Eric Piatkowski     Eric  1610612746               LAC  30.0
#
#    GP   W   L  W_PCT  ...  Position                  Team   Salary   Season  \
# 0  42  13  29  0.310  ...         F   Vancouver Grizzlies  2000000  1999-00
# 1  66  19  47  0.288  ...         F   Vancouver Grizzlies  2200000  2000-01
# 2  66  18  48  0.273  ...         F     Memphis Grizzlies  2400000  2001-02
# 3  75  13  62  0.173  ...        SG  Los Angeles Clippers  2000000  1999-00
# 4  81  31  50  0.383  ...        SG  Los Angeles Clippers  3000000  2000-01
#
#    TEAM_W_PCT     Year  adjusted_salary  next_adjusted_salary  Changed_team  \
# 0       0.268  1999-00          3880000             4136000.0           0.0
# 1       0.280  2000-01          4136000             4392000.0           0.0
# 2       0.280  2001-02          4392000                   NaN           NaN
# 3       0.183  1999-00          3880000             5640000.0           0.0
# 4       0.378  2000-01          5640000             5490000.0           0.0
#
#    YOE
# 0    1
# 1    2
# 2    3
# 3    1
# 4    2
#
# [5 rows x 78 columns]
#
#  Informations sur les données:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10285 entries, 0 to 10284
# Data columns (total 78 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   PLAYER_ID              10285 non-null  int64
#  1   PLAYER_NAME            10285 non-null  object
#  2   NICKNAME               10285 non-null  object
#  3   TEAM_ID                10285 non-null  int64
#  4   TEAM_ABBREVIATION      10285 non-null  object
#  5   AGE                    10285 non-null  float64
#  6   GP                     10285 non-null  int64
#  7   W                      10285 non-null  int64
#  8   L                      10285 non-null  int64
#  9   W_PCT                  10285 non-null  float64
#  10  MIN                    10285 non-null  float64
#  11  FGM                    10285 non-null  float64
#  12  FGA                    10285 non-null  float64
#  13  FG_PCT                 10285 non-null  float64
#  14  FG3M                   10285 non-null  float64
#  15  FG3A                   10285 non-null  float64
#  16  FG3_PCT                10285 non-null  float64
#  17  FTM                    10285 non-null  float64
#  18  FTA                    10285 non-null  float64
#  19  FT_PCT                 10285 non-null  float64
#  20  OREB                   10285 non-null  float64
#  21  DREB                   10285 non-null  float64
#  22  REB                    10285 non-null  float64
#  23  AST                    10285 non-null  float64
#  24  TOV                    10285 non-null  float64
#  25  STL                    10285 non-null  float64
#  26  BLK                    10285 non-null  float64
#  27  BLKA                   10285 non-null  float64
#  28  PF                     10285 non-null  float64
#  29  PFD                    10285 non-null  float64
#  30  PTS                    10285 non-null  float64
#  31  PLUS_MINUS             10285 non-null  float64
#  32  NBA_FANTASY_PTS        10285 non-null  float64
#  33  DD2                    10285 non-null  int64
#  34  TD3                    10285 non-null  int64
#  35  WNBA_FANTASY_PTS       10285 non-null  float64
#  36  GP_RANK                10285 non-null  int64
#  37  W_RANK                 10285 non-null  int64
#  38  L_RANK                 10285 non-null  int64
#  39  W_PCT_RANK             10285 non-null  int64
#  40  MIN_RANK               10285 non-null  int64
#  41  FGM_RANK               10285 non-null  int64
#  42  FGA_RANK               10285 non-null  int64
#  43  FG_PCT_RANK            10285 non-null  int64
#  44  FG3M_RANK              10285 non-null  int64
#  45  FG3A_RANK              10285 non-null  int64
#  46  FG3_PCT_RANK           10285 non-null  int64
#  47  FTM_RANK               10285 non-null  int64
#  48  FTA_RANK               10285 non-null  int64
#  49  FT_PCT_RANK            10285 non-null  int64
#  50  OREB_RANK              10285 non-null  int64
#  51  DREB_RANK              10285 non-null  int64
#  52  REB_RANK               10285 non-null  int64
#  53  AST_RANK               10285 non-null  int64
#  54  TOV_RANK               10285 non-null  int64
#  55  STL_RANK               10285 non-null  int64
#  56  BLK_RANK               10285 non-null  int64
#  57  BLKA_RANK              10285 non-null  int64
#  58  PF_RANK                10285 non-null  int64
#  59  PFD_RANK               10285 non-null  int64
#  60  PTS_RANK               10285 non-null  int64
#  61  PLUS_MINUS_RANK        10285 non-null  int64
#  62  NBA_FANTASY_PTS_RANK   10285 non-null  int64
#  63  DD2_RANK               10285 non-null  int64
#  64  TD3_RANK               10285 non-null  int64
#  65  WNBA_FANTASY_PTS_RANK  10285 non-null  int64
#  66  TEAM_COUNT             10285 non-null  int64
#  67  Rank                   10285 non-null  int64
#  68  Position               10277 non-null  object
#  69  Team                   10285 non-null  object
#  70  Salary                 10285 non-null  int64
#  71  Season                 10285 non-null  object
#  72  TEAM_W_PCT             10285 non-null  float64
#  73  Year                   10285 non-null  object
#  74  adjusted_salary        10285 non-null  int64
#  75  next_adjusted_salary   8324 non-null   float64
#  76  Changed_team           8324 non-null   float64
#  77  YOE                    10285 non-null  int64
# dtypes: float64(29), int64(42), object(7)
# memory usage: 6.1+ MB
# None

# %%
# On regarde le nombre de personnes par tranche de salaire ajusté (ajusté à l'inflation)

# Créer des tranches de salaire personnalisées
salary_brackets = [0, 600000, 1000000, 5000000, 10000000, 15000000, 20000000, 25000000, 30000000, 35000000, 40000000, 45000000, 50000000, float('inf')]
salary_bracket_labels = ['<600K', '600K-1M', '1M-5M', '5M-10M', '10M-15M', '15M-20M', '20M-25M', '25M-30M', '30M-35M', '35M-40M', '40M-45M', '45M-50M', '>50M']

# Catégoriser les salaires ajustés
df['salary_bracket'] = pd.cut(df['adjusted_salary'], bins=salary_brackets, labels=salary_bracket_labels, include_lowest=True)

# Compter le nombre de personnes par tranche
salary_distribution = df['salary_bracket'].value_counts().sort_index()

print("\nNombre de personnes par tranche de salaire:")
print("="*50)
for bracket, count in salary_distribution.items():
    print(f"{bracket:>10}: {count:>5} personnes ({count/len(df)*100:>5.1f}%)")
print("="*50)
print(f"{'Total':>10}: {len(df):>5} personnes")

# Supprimer la colonne salary_bracket du dataframe original
df = df.drop(columns=['salary_bracket'])
# Out:
# Nombre de personnes par tranche de salaire:
# ==================================================
#      <600K:   474 personnes (  4.6%)
#    600K-1M:   503 personnes (  4.9%)
#      1M-5M:  4639 personnes ( 45.1%)
#     5M-10M:  2003 personnes ( 19.5%)
#    10M-15M:   982 personnes (  9.5%)
#    15M-20M:   615 personnes (  6.0%)
#    20M-25M:   451 personnes (  4.4%)
#    25M-30M:   228 personnes (  2.2%)
#    30M-35M:   158 personnes (  1.5%)
#    35M-40M:   107 personnes (  1.0%)
#    40M-45M:    60 personnes (  0.6%)
#    45M-50M:    36 personnes (  0.4%)
#       >50M:    29 personnes (  0.3%)
# ==================================================
#      Total: 10285 personnes

# %% [markdown]
# On remarque qu'environ 5% du dataset sont des joueurs avec un salaire ajusté inférieur à 600k. Or le salaire minimum en 99 était de 300k USD environ, donc environ 600k USD en salaire ajusté. On supprime donc les données associées.

# %%
# Supprimer les lignes où next_adjusted_salary < 600000
print(f"Dataset avant filtrage: {len(df)} lignes")
df = df[df['Salary'] >= 300000]
df = df[df['next_adjusted_salary'] >= 600000]
print(f"Dataset après filtrage sur les salaires): {len(df)} lignes")
# Out:
# Dataset avant filtrage: 10285 lignes
# Dataset après filtrage sur les salaires): 7902 lignes

# %%
adj_salary_season = df.groupby('Season')['adjusted_salary']# Salaire ajusté par saison 
display(adj_salary_season.describe().round(2))
# Out:
#          count         mean          std        min         25%        50%  \
# Season
# 1999-00  153.0   8284408.63   6866815.86   583940.0  3817920.00  5820000.0
# 2000-01  312.0   7141993.46   6999712.79   594080.0  2122520.00  4465000.0
# 2001-02  324.0   7022517.69   7182438.00   607560.0  1830000.00  4529250.0
# 2002-03  221.0   8899159.28   7660890.98   921600.0  3393000.00  6580800.0
# 2003-04  153.0  10599122.61   8652563.03  1033120.0  4176480.00  8120640.0
# 2004-05  101.0  12057540.59   8959943.89  2368440.0  5160000.00  9890000.0
# 2005-06  359.0   7272958.00   6749534.60   661796.0  2008334.50  4897332.0
# 2006-07  347.0   7268892.97   6967652.05   542953.0  1957888.50  4754072.0
# 2007-08  356.0   7547787.76   7298323.78   544504.0  1964945.00  4831320.0
# 2008-09  352.0   7738374.37   7362633.96   663171.0  2108836.50  5132857.5
# 2009-10  346.0   7810792.74   7401971.86   637915.0  2091546.50  5346125.0
# 2010-11  354.0   7419723.60   6982666.29   456797.0  2089367.50  4883147.0
# 2011-12  346.0   7133556.48   6831856.34   439993.0  2051049.25  4748371.0
# 2012-13  322.0   7314700.61   6893230.25   667782.0  2283726.75  4736817.0
# 2013-14  337.0   6972749.20   7043776.12   417000.0  1663496.00  4424370.0
# 2014-15  348.0   6794455.18   6681200.03   420420.0  1641040.50  4418250.0
# 2015-16  339.0   7611951.54   7335642.80   419942.0  1817277.50  4692949.0
# 2016-17  330.0   9980609.58   9303253.23   733686.0  2366779.50  6750000.0
# 2017-18  318.0  11411221.86  10629306.10  1076612.0  2749071.75  7268919.0
# 2018-19  345.0  10563450.94  10943676.53   551202.0  2166581.00  5611500.0
# 2019-20  356.0  10761146.62  11744680.56   444740.0  2218418.50  5603789.5
# 2020-21  380.0  10525861.33  12044665.90   402366.0  2126991.00  5148314.0
# 2021-22  367.0  10510103.34  11718203.85   376484.0  2332722.50  5523984.0
# 2022-23  368.0  11115725.18  12112011.51   397066.0  2367095.75  5886641.0
# 2023-24  368.0  11700305.35  12487644.18   369118.0  2574464.50  6484295.5
#
#                  75%         max
# Season
# 1999-00  10316920.00  33255480.0
# 2000-01   9494000.00  36848000.0
# 2001-02   8852167.50  40992000.0
# 2002-03  11799000.00  45360000.0
# 2003-04  13393600.00  49280000.0
# 2004-05  14534000.00  50678080.0
# 2005-06  10287991.00  33200000.0
# 2006-07   9957850.00  33810000.0
# 2007-08  10140000.00  37053017.0
# 2008-09  10575000.00  37127901.0
# 2009-10  10683250.00  34781906.0
# 2010-11  10392750.00  36961312.0
# 2011-12   9720000.00  36352070.0
# 2012-13  10581118.50  42939865.0
# 2013-14   9440282.00  42330789.0
# 2014-15   9487250.00  32195000.0
# 2015-16  10960000.00  31469585.0
# 2016-17  15435994.50  41800658.0
# 2017-18  17160000.00  49443443.0
# 2018-19  15802500.00  48319729.0
# 2019-20  15196704.75  51094333.0
# 2020-21  13950117.00  53757952.0
# 2021-22  14400000.00  54937159.0
# 2022-23  14861461.75  53357716.0
# 2023-24  15739036.75  55030552.0

# %%
max_salaries_per_season = df.loc[df.groupby('Season')['adjusted_salary'].idxmax(), ['Season', 'PLAYER_NAME', 'adjusted_salary']]
display(max_salaries_per_season)
# Out:
#        Season       PLAYER_NAME  adjusted_salary
# 391   1999-00  Shaquille O'Neal         33255480
# 601   2000-01     Kevin Garnett         36848000
# 602   2001-02     Kevin Garnett         40992000
# 603   2002-03     Kevin Garnett         45360000
# 604   2003-04     Kevin Garnett         49280000
# 396   2004-05  Shaquille O'Neal         50678080
# 397   2005-06  Shaquille O'Neal         33200000
# 606   2006-07     Kevin Garnett         33810000
# 607   2007-08     Kevin Garnett         37053017
# 608   2008-09     Kevin Garnett         37127901
# 956   2009-10       Kobe Bryant         34781906
# 957   2010-11       Kobe Bryant         36961312
# 958   2011-12       Kobe Bryant         36352070
# 959   2012-13       Kobe Bryant         42939865
# 960   2013-14       Kobe Bryant         42330789
# 961   2014-15       Kobe Bryant         32195000
# 2984  2015-16      LeBron James         31469585
# 2985  2016-17      LeBron James         41800658
# 5550  2017-18     Stephen Curry         49443443
# 5551  2018-19     Stephen Curry         48319729
# 5552  2019-20     Stephen Curry         51094333
# 5553  2020-21     Stephen Curry         53757952
# 5554  2021-22     Stephen Curry         54937159
# 5555  2022-23     Stephen Curry         53357716
# 5556  2023-24     Stephen Curry         55030552

# %% [markdown]
# # Statistiques Descriptives
# ## Données utilisées
#
# Nous avons construits la base de données "NBA_Stats"
#
# Elle présente de nombreuses variables d’intérêt pour notre étude :
#
# **adjusted_salary :** *Salaire brut sur une saison, ajusté pour permettre la comparaison entre les différentes saisons*
# **PTS :** *Nombre de points inscrit par match en moyenne sur une saison régulière de 82 matchs*
# **REB :** *Nombre de rebonds capté par match en moyenne sur une saison régulière de 82 matchs*
# **AST :** *Nombre de passes décisives effectuée par match en moyenne sur une saison régulière de 82 matchs*
# **STL :** *Nombre d'interceptions par match en moyenne sur une saison régulière de 82 matchs*
# **BLK :** *Nombre de tirs contré par match en moyenne sur une saison régulière de 82 matchs*
# **PLUS_MINUS :** *Différence entre les points inscrits et encaissés par l'équipe lorsque le joueur est présent sur le terrain, en moyenne sur une saison régulière de 82 matchs*
#
# **XXX_RANK :** *Classement d'un joueur sur une saison régulière dans la catégorie statistique XXX (PTS, REB, AST, STL, BLK)*
#
# Les salaires des joueurs reposent ils uniquement sur leur performances sur le terrain?
# Regardons l'évolution des 5 statistiques principalement regardées (par le grand public) en NBA ainsi que le temps de jeu.

# %%
plt.plot(adj_salary_season.max(), c='red',linewidth = 1, label='Max')
plt.plot(adj_salary_season.mean(), c='blue',linewidth = 1, label='Mean')
plt.plot(adj_salary_season.median(), c='green',linewidth = 1, label='Median')
plt.plot(adj_salary_season.min(), c='yellow',linewidth = 1, label='Min')
plt.title("NBA salary trends (2000-2025)")
plt.xlabel("Season")
plt.tick_params(axis='x', rotation=45, labelsize='8')
plt.ylabel("Salary")
plt.legend()
plt.show()

# %%
df['total_minutes'] =  df['MIN'] * df['GP']
time_played_season = df.groupby('Season')['total_minutes']    # Nombre de minutes jouées par saison en moyenne

# %%
def plot_stat(stat_name, placement):
    '''
    Trace le un graphique avec la valeur max, min, moyenne et médiane d'une variable
    '''
    placement.set_title(f'{stat_name}/game evolution') 
    placement.plot(df.groupby('Season')[stat_name].max(), c='red',linewidth = 1, label='Max')
    placement.plot(df.groupby('Season')[stat_name].mean(), c='blue',linewidth = 1, label='Mean')
    placement.plot(df.groupby('Season')[stat_name].median(), c='green',linewidth = 1, label='Median')
    placement.plot(df.groupby('Season')[stat_name].min(), c='yellow',linewidth = 1, label='Min')
    placement.tick_params(axis='x', rotation=45, labelsize='8')

# %%
fig, axes = plt.subplots(2, 3, figsize=(16, 10))
fig.suptitle('Evolution des statistiques majeures (2000-2025)', fontsize=20)
labels = []
labels.extend(['Max', 'Mean', 'Median', 'Min'])
plot_stat('PTS', axes[0,0])


plot_stat('REB', axes[0,1])
plot_stat('AST', axes[0,2])
plot_stat('STL', axes[1,0])
plot_stat('BLK', axes[1,1])
plot_stat('total_minutes', axes[1,2])
axes[1,2].set_title(f'Minutes/game evolution')

fig.legend(labels, loc='upper center', bbox_to_anchor=(0.5, 0.94), ncol=4)
plt.show()

# %% [markdown]
# On n'observe pas d'augmentation massive d'aucune des 5 statistiques principales qui semble pouvoir totalement expliqué la hausse des salaires. On peut aussi penser que les joueurs jouent plus et que c'est pour cela qu'ils sont mieux payés qu'avant. Mais la encore aucune évolution notable du temps de jeu, il semble même plutôt diminuer.

# %%
def stat_norm(stat_name):
    #Moyenne normalisé par rapport à la moyenne en 1999-00
    mean_stat_00 = df[df['Season']=='1999-00'][stat_name].mean()
    mean_stat_season = df.groupby('Season')[stat_name].mean()
    return mean_stat_season/mean_stat_00

# %%
plt.figure(figsize=(8, 6))
plt.suptitle('Evolution des statistiques majeures et du salaire (2000-2025)', fontsize=15)
labels = []
labels.extend(['Salary(adj)', 'PTS', 'REB', 'AST', 'STL', 'BLK'])

plt.plot(stat_norm('adjusted_salary'),linewidth = 5, label= 'Salary')
plt.plot(stat_norm('PTS'),linewidth = 5, label= 'PTS')

plt.plot(stat_norm('REB'),linewidth = 1, label= 'REB')
plt.plot(stat_norm('AST'),linewidth = 1, label= 'AST')
plt.plot(stat_norm('STL'),linewidth = 1, label= 'STL')
plt.plot(stat_norm('BLK'),linewidth = 1, label= 'BLK')
plt.axhline(y=1,linestyle = '--')

plt.title("Normalisée par rapport à la saison 1999-00")
plt.legend(labels, loc='upper center', bbox_to_anchor=(0.5, 0.94), ncol=4)
plt.tick_params(axis='x', rotation=45, labelsize='8')
plt.show()

# %% [markdown]
# ATTENTION : Le boom des salaires et des performances autour de 2004 provient probablement d'un problème de données, en effet on possède un nombre faible de joueurs pour les saisons de 2002-03 à 2004-05, on peut rationnellement penser que les informations disponibles concernent les meilleurs joueurs, donc ceux qui font les meilleures performances et qui sont le mieux payés.
# Hormis cette "explosion", le salaire comme les performances moyennes restent à peu près stable du début des années 2000 à 2015.
# A partir de 2016 on observe une augmentaion du salaire moyen et des performances moyennes mais proportionnelement moins importante que l'augmentation du salaire. L'augmentation des

# %% [markdown]
# # Cohérence entre salaire et performance sur la saison en cours

# %% [markdown]
# ## Régressions Linéaires

# %% [markdown]
# ## 1) Régression linéaire simple

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
df.copy()
print()

# %%
print(f"Nombre de joueurs à 0 pts : {(df['PTS']==0).sum()}")
print(f"Nombre de joueurs avec un salaire nul : {(df['adjusted_salary']==0).sum()}")
# Out:
# Nombre de joueurs à 0 pts : 8
# Nombre de joueurs avec un salaire nul : 0

# %% [markdown]
# On peut donc envisager un passage au logarithme pour des représentation en Log - Niveau, par exemple, car on ne perd pas trop de données en supprimant les valeurs nulles (seulement 45 suppressions concernant les joueurs n'ayant marqué aucun point).

# %%
df_log = df[(df['PTS'] > 0) & (df['adjusted_salary'] > 0)].copy()
df_log['log_PTS'] = np.log(df_log['PTS'])
df_log['log_salary'] = np.log(df_log['adjusted_salary'])

# Regression    Niveau - Niveau
reg_pts = smf.ols('adjusted_salary ~ PTS', data=df_log).fit()
df_log['salary_predicted_pts'] = reg_pts.predict(df_log['PTS'])    # Salaire prédit par le modèle   Niveau - Niveau

# Regression    Niveau - Log
reg_pts_niv_log = smf.ols('adjusted_salary ~ log_PTS', data=df_log).fit()
df_log['salary_predicted_pts_niv_log'] = reg_pts_niv_log.predict(df_log['log_PTS'])  # Salaire prédit par le modèle   Niveau - Log

# Regression    Log - Niveau
reg_pts_log_niv = smf.ols('log_salary ~ PTS', data=df_log).fit()
df_log['log_salary_predicted_pts'] = reg_pts_log_niv.predict(df_log['PTS'])
df_log['salary_predicted_pts_log_niv'] = np.exp(df_log['log_salary_predicted_pts']) # Salaire prédit par le modèle   Log - Niveau

# Regression    Log - Log
reg_pts_log_log = smf.ols('log_salary ~ log_PTS', data=df_log).fit()
df_log['log_salary_predicted_log_pts'] = reg_pts_log_log.predict(df_log['log_PTS'])
df_log['salary_predicted_pts_log_log'] = np.exp(df_log['log_salary_predicted_log_pts'])  # Salaire prédit par le modèle   Log - log

# %%
# Comparaison du R^2 des différents modèles

tab_R2 = pd.DataFrame({
    'Modèle': ['Niveau–Niveau', 'Niveau–Log', 'Log–Niveau', 'Log–Log'],
    'R2': [ reg_pts.rsquared , reg_pts_niv_log.rsquared , reg_pts_log_niv.rsquared, reg_pts_log_log.rsquared]
})
tab_R2['R2'] = tab_R2['R2'].round(3)
tab_R2_styled = (
    tab_R2.style
    .highlight_max(subset=['R2'], color='lightgreen')
    .format({'R2': '{:.3f}'}) 
)

display(tab_R2_styled)
# Out:
# <style type="text/css">
# #T_9562d_row0_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_9562d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9562d_level0_col0" class="col_heading level0 col0" >Modèle</th>
#       <th id="T_9562d_level0_col1" class="col_heading level0 col1" >R2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9562d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9562d_row0_col0" class="data row0 col0" >Niveau–Niveau</td>
#       <td id="T_9562d_row0_col1" class="data row0 col1" >0.387</td>
#     </tr>
#     <tr>
#       <th id="T_9562d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9562d_row1_col0" class="data row1 col0" >Niveau–Log</td>
#       <td id="T_9562d_row1_col1" class="data row1 col1" >0.283</td>
#     </tr>
#     <tr>
#       <th id="T_9562d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9562d_row2_col0" class="data row2 col0" >Log–Niveau</td>
#       <td id="T_9562d_row2_col1" class="data row2 col1" >0.365</td>
#     </tr>
#     <tr>
#       <th id="T_9562d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9562d_row3_col0" class="data row3 col0" >Log–Log</td>
#       <td id="T_9562d_row3_col1" class="data row3 col1" >0.336</td>
#     </tr>
#   </tbody>
# </table>

# %%
def plot_rls(x, y_pred, reg_func, placement,  y = 'adjusted_salary', color = 'blue', data = df):
    '''
    x : Variable explicative
    y : Variable expliquée
    y_pred : Prédiction de la variable expliquée
    placement : Localisation de la fenêtre
    reg_func : Fonction de regression utilisée
    
    Nuage de points du salaire prédit (y_pred) par la Reg Linéaire Simple par rapport à la variable x
    '''
    placement.scatter(data[x], data[y], color = color, alpha=0.5 )
    placement.plot(data[x], data[y_pred], c='red', lw=2)
    placement.set_xlabel(f'{x}/match')
    placement.set_ylabel('Salaire ($)')
    placement.set_title(f'Prédiction   Salaire ~ {x} (R^2 = {reg_func.rsquared:.3f})')
    placement.ticklabel_format(style='plain', axis='both')

# %%
fig, axes = plt.subplots(2, 2, figsize=(16, 12))
plt.suptitle(f" Reg. Linéaire Simple : Salaire ~ PTS")

# Regression    Niveau - Niveau
plot_rls('PTS','salary_predicted_pts', reg_pts, axes[0,0], data = df_log)
axes[0,0].set_title(f'Prédiction   Niveau - Niveau (R^2 = {reg_pts.rsquared:.3f})')

# Regression    Niveau - Log
plot_rls('log_PTS','salary_predicted_pts_niv_log', reg_pts_niv_log, axes[0,1], data = df_log)
axes[0,1].set_title(f'Prédiction   Niveau - Log (R^2 = { reg_pts_niv_log.rsquared:.3f})')
axes[0,1].set_ylabel('Log Salaire')

# Regression    Log - Niveau
plot_rls('PTS','log_salary_predicted_pts', reg_pts_log_niv, axes[1,0], y = 'log_salary', data = df_log)
axes[1,0].set_title(f'Prédiction   Log - Niveau (R^2 = {reg_pts_log_niv.rsquared:.3f})')

# Regression    Log - Log
plot_rls('PTS','salary_predicted_pts_log_log', reg_pts_log_log, axes[1,1], data = df_log)
axes[1,1].set_title(f'Prédiction Log - Log (R^2 = {reg_pts_log_log.rsquared:.3f})')

plt.show()

# %% [markdown]
# Que ce soit via les R2 ou par observasition graphique, on voit que le modèle avec la meilleure qualité de prédiction reste le plus simple : le modèle Niveau - Niveau (Salaire ~ PTS).

# %%
# Regression    Niveau - Niveau (Salaire ~ PTS)
reg_pts = smf.ols('adjusted_salary ~ PTS', data=df).fit()
df['salary_predicted_pts'] = reg_pts.predict(df['PTS'])    

# Regression   Niveau - Niveau  (Salaire ~ +/-)
reg_plus_minus = smf.ols('adjusted_salary ~ PLUS_MINUS', data=df).fit()
df['salary_predicted_plus_minus'] = reg_plus_minus.predict(df['PLUS_MINUS'])

# %%
def plot_error(y_pred, placement, y = 'adjusted_salary', color = 'blue', c_line ='red', nom_reg = "" ,data = df):
    '''
    y : variable expliquée
    y_pred : Prédiction de la variable expliquée
    placement : Localisation de la fenêtre
    
    Diagramme de la distribution des erreurs de prédiction du modèle
    '''
    errors_func = data[y] - data[y_pred]
    placement.hist(errors_func, bins=50, color = color, edgecolor='black', density = True)
    placement.set_xlabel('Erreur de prédiction ($)')
    placement.set_ylabel('Fréquence')
    placement.set_title(f'Distribution des erreurs de prédiction')
    placement.axvline(x=0, color= c_line, linestyle='--', linewidth=2)
    placement.ticklabel_format(style='plain', axis='x')
    placement.tick_params(axis='x', rotation=45, labelsize='8')

    print(f"\n Statistiques des erreurs ({nom_reg}):")
    print(f"   Erreur moyenne: ${errors_func.mean():,.0f}")
    print(f"   Écart-type des erreurs: ${errors_func.std():,.0f}")

# %%
# Visualiser les prédictions vs valeurs réelles
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# Regression linéaire simple du Salaire ~ PTS
plot_rls('PTS','salary_predicted_pts', reg_pts, axes[0,0])

# Distribution des erreurs
plot_error('salary_predicted_pts',axes[0,1] , nom_reg = "Salaire ~ PTS")


# Regression linéaire simple du Salaire ~ (+/-)
plot_rls('PLUS_MINUS', 'salary_predicted_plus_minus', reg_plus_minus, axes[1,0], color = 'grey')

# Distribution des erreurs
plot_error('salary_predicted_plus_minus', axes[1,1], color ='grey', nom_reg = "Salaire ~ (+/-)")

plt.tight_layout()
plt.show()
# Out:
#  Statistiques des erreurs ($Salaire ~ PTS):
#    Erreur moyenne: $0
#    Écart-type des erreurs: $7,126,288
#
#  Statistiques des erreurs ($Salaire ~ (+/-)):
#    Erreur moyenne: $0
#    Écart-type des erreurs: $8,704,393

# %% [markdown]
# Pour estimer le salaire des joueurs, la première composante que l'on pense à étudier est le nombre de points inscrits par match. Dans un premier temps, on étudie la régression linéaire simple du salaire sur la moyenne de points inscrits par match ( Salaire ~ PTS ), pour obtenir une première prédiction simple du salaire.
#
# Mais on peut aussi considérer d'autres statistiques qui illustrent mieux les apports globaux d'un joueur sur le terrain et pas uniquement sa capacité à marquer.
# Le Plus-Minus est une statistique qui mesure l'impact d'un joueur sur un match en comparant les points marqués et encaissés par son équipe lorsqu'il est sur le terrain. Cela permet donc d'observer dans une certaine mesure le poids d'un joueur individuellement, non seulement en attaque (Nombre de points marqués) mais aussi en défense (Nombre de points encaissés), il tient aussi compte de la dimension collective de l'équipe et donc de l'importance du joueur en question dans le bon fonctionnement de celle-ci.
# On remarque cependant que la régression linéaire simple avec cette mesure de performance présente certains problème, notamment:
#
# - Un salaire prédit négatif pour les joueurs avec un +/- mauvais (Hors les joueurs ne payent pas pour jouer en NBA)
# - Une dispersion du nuage de points importante, pour une même performance selon l'indicateur +/- le salaire (réel) peut énormément varier ( cela peut s'expliquer par les énormes salaires des joueurs stars des équipes en difficulté, en effet si l'equipe perd souvent le +/- des joueurs de l'équipe est rarement bon et il en va de même pour le joueur star)
# - Un R^2 faible (le +/- explique une faible portion du salaire)
#
# De manière générale, les régressions linéaires simples seront insuffisantes pour prédire précisement les salaires.

# %% [markdown]
# ### TEST A SUPPR

# %%
df_sorted_age = df.sort_values('AGE')
df_sorted_age['age2'] = df_sorted_age['AGE']**2
reg_age = smf.ols('adjusted_salary ~ age2', data=df_sorted_age).fit()
df_sorted_age['salary_predicted_age2'] = reg_age.predict(df_sorted_age['age2'])

salary_lowess_age = lowess(df['adjusted_salary'], df['PTS'], frac=0.3)

# %%
# Regression   Niveau - Niveau  (Salaire ~ +/-)
reg_age = smf.ols('adjusted_salary ~ AGE', data=df).fit()
df['salary_predicted_age'] = reg_age.predict(df['AGE'])

salary_lowess_pts = lowess(df['adjusted_salary'], df['PTS'], frac=0.3)

# %%
# Visualiser les prédictions vs valeurs réelles
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Regression linéaire simple du Salaire ~ PTS
plot_rls('AGE','salary_predicted_age2', reg_age, axes[0])

# Distribution des erreurs
plot_error('salary_predicted_age2',axes[1],)

# %% [markdown]
# ### Significativité pratique vs. statistique (Points , +/-)
# On a vu que 'PTS' et '+/-' semble avoir un effet (pratique) sur les salaires, mais sont-ils vraiment significatifs statistiquement.
# On va utiliser un test de Student pour le vérifier.
#
# H0 : " Le nombre de points inscrits en moyenne n'a pas d'effet significatif sur les salaires "   vs.    H1 :" L'effet de 'PTS' sur les salaires est significatif "
#
# Avec un modèle de régression linéaire simple (Niveau - Niveau) : Salaires = B0 + B1 * PTS + e
# cela revient à tester     H0: " B1=0 "   vs.   H1: "B1 !=0 "

# %%
print(f"Coef de 'PTS' :  {round(reg_pts.params['PTS'],0)}")         # Significativité pratique de 'PTS' 
print(f"P-valeur de 'PTS' :  {round(reg_pts.pvalues['PTS'],0)}")    # Significativité statistique de 'PTS'
# Out:
# Coef de 'PTS' :  920667.0
# P-valeur de 'PTS' :  0.0

# %% [markdown]
# On a p-valeur < 0.01, c'est à dire que l'on rejette l'hypothèse H0 au seuil de 1%, donc l'effet du nombre de points inscrits en moyenne  sur le salaire, est statistiquement significatif au seuil de 1%.
# La p-valeur est même approximativement nulle, donc la variable est significative à un seuil extrèmement faible.

# %%
print(f"Coef de '+/-' :  {round(reg_plus_minus.params['PLUS_MINUS'],0)}")        # Significativité pratique de 'PLUS_MINUS'
print(f"P-valeur de '+/-' :  {round(reg_plus_minus.pvalues['PLUS_MINUS'],3)}")   # Significativité statistique de 'PLUS_MINUS'
# Out:
# Coef de '+/-' :  903854.0
# P-valeur de '+/-' :  0.0

# %% [markdown]
# On a p-valeur < 0.01, c'est à dire que l'on rejette l'hypothèse H0 au seuil de 1%, donc l'effet du (+/-) sur le salaire, est statistiquement significatif au seuil de 1%.

# %% [markdown]
# Conclusion : Les variables 'PTS' et '+/-' ont un effet statistiquement significatif au seuil de 1% sur 'adjusted_salary' dans les modèles de régression linéaire simple étudiés.
# En pratique, chacune à un effet très fort sur les salaires.
# Une variation de 1 point inscrits en moyenne correspond à une variation de 920 000 USD dans le salaire.
# Une variation de 1 du '+/-' correspond à une variation de 903 000 USD dans le salaire.

# %% [markdown]
# ## 2) Régression locale simple (LOWESS)
# ### Peut on trouver une régression avec une courbe de tendance plus proche du nuage de points ?
# Plutôt que d’utiliser la méthode des MCO on va utiliser la méthode lowess (locally weighted scatterplot smoothing) qui agrège plusieurs estimations locales tenant compte des valeurs voisines en une estimation globale.
# Cela permet d’obtenir une courbe qui modélisent mieux les valeurs extrêmes et tient plus compte des fluctuations locales des salaires. On peut notamment voir si l'elstacité entre salaire et 'PTS' ou '+/-' n'est pas constante.

# %%
from numpy import interp

lowess = sm.nonparametric.lowess
salary_lowess_pts = lowess(df['adjusted_salary'], df['PTS'], frac=0.3)
salary_lowess_plus_minus = lowess(df['adjusted_salary'], df['PLUS_MINUS'], frac=0.3)

PTS_smooth = salary_lowess_pts[:, 0]
salary_smooth_pts = salary_lowess_pts[:, 1]
df['salary_predicted_lowess_pts'] = interp(df['PTS'], PTS_smooth, salary_smooth_pts)


PLUS_MINUS_smooth = salary_lowess_plus_minus[:, 0]
salary_smooth_plus_minus = salary_lowess_plus_minus[:, 1]
df['salary_predicted_lowess_plus_minus'] = interp(df['PLUS_MINUS'], PLUS_MINUS_smooth, salary_smooth_plus_minus)

# %%
import matplotlib.lines as mlines

# Visualiser les prédictions vs valeurs réelles
fig, axes = plt.subplots(2, 3, figsize=(16, 16))
fig.suptitle('Prédiction des salaires en fonction des points inscrits selon 2 méthodes d estimations', fontsize=20)

#Légende
labels = ['MCO','LOWESS']
color_lab = ['red','lime']
handles = [mlines.Line2D([], [], color=c) for c in color_lab]


# Graphique 1: Regression Salaire ~ PTS
plot_rls('PTS','salary_predicted_pts', reg_pts, axes[0,0])
axes[0,0].plot(PTS_smooth, salary_smooth_pts, c='lime', lw=2, label="Courbe LOWESS")           # Courbe  de tendance de la la prédiction par la méthode LOWESS
axes[0,0].axvline(x=np.median(df['PTS']), color='black', linestyle='--', linewidth=2)          # Mediane 
axes[0,0].axvline(x=np.percentile(df['PTS'], 90), color='black', linestyle='--', linewidth=2)  # Centile 90 : 90 % des joueurs inscrivent moins de pts que ce seuil


# Graphique 2: Distribution des erreurs (MCO)
plot_error('salary_predicted_pts',axes[0,1] , nom_reg = "Salaire ~ PTS (MCO)")
axes[0,1].set_title('Distribution des erreurs de prédiction (MCO)')

# Graphique 3: Distribution des erreurs (Lowess)
plot_error('salary_predicted_lowess_pts',axes[0,2], c_line = 'lime', nom_reg = "Salaire ~ PTS (Lowess)")
axes[0,2].set_title('Distribution des erreurs de prédiction (Lowess)')


# Graphique 4: Regression Salaire ~ (+/-)
plot_rls('PLUS_MINUS', 'salary_predicted_plus_minus', reg_plus_minus, axes[1,0], color = 'grey')
axes[1,0].plot(PLUS_MINUS_smooth, salary_smooth_plus_minus, c='lime', lw=2, label="Courbe LOWESS")
axes[1,0].axvline(x=np.median(df['PLUS_MINUS']), color='black', linestyle='--', linewidth=2)         
axes[1,0].axvline(x=np.percentile(df['PLUS_MINUS'], 90), color='black', linestyle='--', linewidth=2)

# Graphique 5: Distribution des erreurs (MCO)
plot_error('salary_predicted_plus_minus', axes[1,1], color ='grey', nom_reg = "Salaire ~ (+/-) (MCO)")
axes[1,1].set_title('Distribution des erreurs de prédiction (MCO)')

# Graphique 6: Distribution des erreurs (Lowess)
plot_error('salary_predicted_lowess_plus_minus', axes[1,2], color ='grey', c_line = 'lime', nom_reg = "Salaire ~ (+/-) (Lowess)")
axes[1,2].set_title('Distribution des erreurs de prédiction (Lowess)')



fig.legend(handles=handles, labels=labels, loc='center', bbox_to_anchor=(0.5, 0.94))
plt.show()
# Out:
#  Statistiques des erreurs (Salaire ~ PTS (MCO)):
#    Erreur moyenne: $0
#    Écart-type des erreurs: $7,126,288
#
#  Statistiques des erreurs (Salaire ~ PTS (Lowess)):
#    Erreur moyenne: $1,294,707
#    Écart-type des erreurs: $7,100,717
#
#  Statistiques des erreurs (Salaire ~ (+/-) (MCO)):
#    Erreur moyenne: $0
#    Écart-type des erreurs: $8,704,393
#
#  Statistiques des erreurs (Salaire ~ (+/-) (Lowess)):
#    Erreur moyenne: $2,235,533
#    Écart-type des erreurs: $8,460,466

# %%
print(f"Centile 90 'PTS': {np.percentile(df['PTS'], 90)}")
print(f"Mediane 'PTS': {np.median(df['PTS'])}")
# Out:
# Centile 90 'PTS': 18.9
# Mediane 'PTS': 8.8

# %% [markdown]
# On observe bien que l'élasticité du salaire par rapport aux 'PTS' ou '+/-' n'est pas constante dans les 2 modèles d'estimation avec LOWESS. On observe que le salaire prédit par le modèle LOWESS, est presque constant pour les joueurs ayant un '+/-' négatif ou nul, et qu'il explose pour les joueurs pour lequels il est fortement positif. En pratique les joueurs avec un '+/-' positif sont les bons ou très bon joueurs qui sont donc grassement payés, si les joueurs ont un '+/-' négatif, cela signifie qu'il font en moyenne 'perdre' l'équipe et leur valeur diminue en conséquence.
#
# Pour le modèle Salaire ~ PTS, avec LOWESS, on remarque que la courbe de tendance est convexe, l'effet marginal d'un point supplémentaire sur le salaire est beaucoup plus élevé lorsque l'on inscrit en moyenne plus de 20 points par match que lorsque l'on en inscrit moins de 5. Il est en effet beaucoup plus difficile d'augmenter son apport offensif lorsqu'il est déjà élevé car le temps de jeu est limité à 48 minutes par match, donc seul les meilleurs sont capables d'inscrire plus de 20 points par match ce qui se reflètent dans leur salaire.
#
# On peut par exemple définir arbitrairement 3 catégories de joueurs : les "bench players", les "role players" et les "franchise player".
#
# Les "bench players" sont souvent des joueurs remplacant qui ne possèdent que peu de temps de jeu et qui ne peuvent généralement pas inscrire une forte quantité de points. Dans notre cas, les "role players" sont des joueurs titulaires ou remplacants avec un temps de jeu conséquent et qui ont donc la possibilité d'inscrire plus de points que les "bench players" mais pas autant que les "franchise players", ils sont également mieux payés que les "role player". Les "franchise players" quant à eux sont des joueurs stars, ce sont généralement les leaders offensifs de leur équipe, ce qui leur permet d'inscire un nombre conséquent de paniers et donc de points. On compte généralement un "franchise player" par équipe (pour simplifier on considère que le top 10% des meilleurs scoreurs sont les "franchise player"), c'est aussi généralement sur lui que l'équipe investit le plus, ces joueurs ont la plupart du temps les salaires les plus élevés (exeption faite des rares franchise players très jeunes et encore sous contrat "rookie", un contrat à rémunération limitée).
#
# Sur le graphique 1, avant la première droite vertivale (Mediane des points inscrits) on lit que les salaires prédits des "bench player" sont plutôt constant, on observe une augmentation des rémunérations pour les bons joueurs et enfin une explosion des salaires pour les meilleurs scoreurs, ceux qui inscrivent plus de 19 pts par match (plus que 90% des joueurs de la ligue).

# %% [markdown]
# ## 3) Régressions linéaires multiples
#
# Avant de faire des régressions mutliples, normalisons les variables explicatives:

# %% [markdown]
# ## A VERIFIER (NORMALISATION DES VARIABLES)

# %%
def plot_rlm( y_pred, placement,  y = 'adjusted_salary', color = 'blue', data = df):
    '''
    y : Variable expliquée
    y_pred : Prédiction de la variable expliquée par la RLM
    placement : Localisation de la fenêtre
    
    Nuage de points de y_pred (salaire prédit) par la Reg Linéaire Multiple par rapport à y (salaire réel)
    '''
    placement.scatter(df[y], df[y_pred], alpha=0.5)
    placement.plot([df[y].min(), df[y].max()],
             [df[y].min(), df[y].max()], 'r--', lw=2, label = "Prédiction parfaite") # Droite de prédiction parfaite
    placement.set_xlabel('Salaire réel ($)')
    placement.set_ylabel('Salaire prédit ($)')
    placement.set_title('Prédictions vs Valeurs réelles ')
    placement.ticklabel_format(style='plain', axis='both')

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

X = df[["PTS", "REB", "AST", "STL", "BLK"]]
y = df["adjusted_salary"]

X_train, X_test, y_train, y_test = train_test_split(       # Créer un échantillon d'entrainement de 70% des données et de test de 30% des données
    X, y, test_size=0.3, random_state=42
)

X_train_scaled = X_train.copy()
X_test_scaled = X_test.copy()

scalers = {}

#Normalise colonne par colonne
for col in X.columns:
    scaler = StandardScaler()
    
    X_train_scaled[col] = scaler.fit_transform(X_train[[col]])
    X_test_scaled[col] = scaler.transform(X_test[[col]])
    
    scalers[col] = scaler
    
# Moyenne et Variance avant normalisation
X_test.describe().loc[['mean', 'std']].round(3)
# Out:
#         PTS    REB    AST    STL    BLK
# mean  9.109  3.823  1.958  0.671  0.454
# std   6.193  2.507  1.801  0.422  0.497

# %%
X_test_scaled.describe().loc[['mean', 'std']].round(3)
# OK on a bien une moyenne ~ 0  et Variance ~ 1
# Out:
#         PTS    REB    AST    STL    BLK
# mean  0.038  0.031 -0.012  0.002  0.058
# std   1.012  1.041  0.964  0.976  1.099

# %%
import matplotlib.pyplot as plt
import numpy as np

import scipy.stats

# Histogramme avant normalisation
plt.figure(figsize=(12,5))

y = scipy.stats.norm.pdf(np.linspace(-5,5),X_test_scaled['PTS'].mean(),X_test_scaled['PTS'].std())

plt.subplot(1, 2, 1)
plt.hist(X_test['PTS'], bins=50, edgecolor='black', density= True)
plt.axvline(x=X_test['PTS'].mean(), color='red', linestyle='--', linewidth=2, label='Moyenne')
plt.xlabel('PTS')
plt.ylabel('Fréquence')
plt.title('Avant normalisation')
plt.legend()

plt.plot(np.linspace(-5,5),y)

# Histogramme après normalisation (StandardScaler)
plt.subplot(1, 2, 2)
plt.hist(X_test_scaled['PTS'], bins=50, edgecolor='black' , density= True)
plt.axvline(x=X_test_scaled['PTS'].mean(), color='red', linestyle='--', linewidth=2, label='Moyenne')
plt.xlabel('PTS (standardisé)')
plt.ylabel('Fréquence')
plt.title('Après normalisation')
plt.legend()

plt.plot(np.linspace(-5,5),y)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##

# %% [markdown]
# ### Les statistiques individuelles habituelles de jeu (PTS, REB, AST, STL, BLK) prédisent-elles les salaires des joueurs?
# On va désormais considérer une régression linéaire multiple qui tient compte des 5 principales statistiques ( PTS, REB, AST, STL, BLK ):
#           Salaire = B0 + B1xPTS + B2xREB + B3xAST + B4xSTL + B5xBLK + e

# %%
reg5 = smf.ols('adjusted_salary ~ PTS + REB + AST + STL + BLK', data=df).fit()
df['salary_predicted_5'] = reg5.predict(df[['PTS','REB','AST','STL','BLK']])

print(f"Erreur moyenne = {(reg5.resid.mean()).round(5)}") # On a un estimateur sans biais
# Out:
# Erreur moyenne = 0.0

# %% [markdown]
# On souhaite savoir si les statistiques individuelles habituelles ont un impact sur le salaire, c'est à dire si au moins l'une d'elle permet d'expliquer le salaire, lorqu'on intègre les 5 au modèle.
# On cherche donc à faire un test de Fisher:
#
# H0 : " B1 = B2 = B3 = B4 = B5 = 0 "   vs    H1 : " (B1 != 0) ou (B2 != 0) ou (B3 != 0) ou (B4 != 0) ou (B5 != 0) "

# %%
print( "F-stat : ", round(reg5.fvalue))
print( "F-stat : ", reg5.f_pvalue)
# Out:
# F-stat :  1193
# F-stat :  0.0

# %% [markdown]
# On observe que la  p-valeur de m
# la statisique de Fisher est approximativement nulle, ce qui signifie que l'on rejette H0 à un seuil proche de 0, donc ces 5 indicateurs ont un effet conjointement significatif sur le salaire.
# Ces 5 statistiques permettent donc de prédire en partie le salaire des joueurs.
# Cependant on observe que le nombre moyen d'interceptions par match est lié négativement au salaire dans notre modèle, ce qui semble incohérent. Une interception n'est pas une action négative au basket-ball, et a même un effet positif pour la victoire de son équipe, il est donc étonnant qu'elle impacte négativement le salaire des joueurs. Mais on peut aussi penser que les statistiques défensives comme les interceptions ont moins d'effet sur le salaire que les points inscrits, en considérant la défense comme une "basse besogne" que les stars font moins l'effort de faire.

# %%
# Visualiser les prédictions vs valeurs réelles
fig, axes = plt.subplots(1, 2, figsize=(16, 6))
plt.suptitle(f"RLM (Non-normalisée):  Salaire ~ PTS + REB + AST + STL + BLK ( R^2 = {reg5.rsquared:.2f}) ")

# Graphique 1: Qualité de la RLM
plot_rlm('salary_predicted_5', axes[0])

# Graphique 2: Distribution des erreurs
plot_error('salary_predicted_5',axes[1] , nom_reg = "Salaire ~ PTS + REB + AST + STL + BLK")
# Out:
#  Statistiques des erreurs (Salaire ~ PTS + REB + AST + STL + BLK):
#    Erreur moyenne: $0
#    Écart-type des erreurs: $6,656,135

# %% [markdown]
# ### Meme qu'en dessous avec utilisation des fonctions (MARCHE PAS POUR LE MOMENT)

# %%
df_scaled_reg = X_test_scaled.copy()
df_scaled_reg['adjusted_salary'] = y_test

reg5_norm = smf.ols('adjusted_salary ~ PTS + REB + AST + STL + BLK', data=df_scaled_reg).fit()
df_scaled_reg['salary_predicted_5_norm'] = reg5_norm.predict(df[['PTS','REB','AST','STL','BLK']])

# %%
# Visualiser les prédictions vs valeurs réelles
fig, axes = plt.subplots(1, 2, figsize=(16, 6))
plt.suptitle(f"RLM (Normalisée):  Salaire ~ PTS + REB + AST + STL + BLK ( R^2 = {reg5.rsquared:.2f}) ")

# Graphique 1: Qualité de la RLM
plot_rlm('salary_predicted_5_norm', axes[0], data = df_scaled_reg )

# Graphique 2: Distribution des erreurs
plot_error('salary_predicted_5_norm',axes[1] , data = df_scaled_reg, nom_reg = "Salaire ~ PTS + REB + AST + STL + BLK")
# Out:
#  Statistiques des erreurs (Salaire ~ PTS + REB + AST + STL + BLK):
#    Erreur moyenne: $-49,121,560
#    Écart-type des erreurs: $26,636,595

# %% [markdown]
# ###

# %%
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import r2_score, mean_squared_error 
model = LinearRegression() 

# Entraînement 
model.fit(X_train_scaled, y_train) 
# Prédictions 
y_pred = model.predict(X_test_scaled)

# %%
plt.figure(figsize=(16, 6))
plt.suptitle(f"RLM : Salaire ~ PTS + REB + AST + STL + BLK ( R^2 = {r2_score(y_test, y_pred):.2f}) ")

# --- Graphique 1 : Prédictions vs Valeurs réelles ---
plt.subplot(1, 2, 1)
plt.scatter(y_test, y_pred, alpha=0.5)
plt.plot([y_test.min(), y_test.max()], [y_pred.min(), y_pred.max()], 'r--', lw=2)
plt.xlabel('Salaire réel ($)')
plt.ylabel('Salaire prédit ($)')
plt.title('Prédictions vs Valeurs réelles')
plt.ticklabel_format(style='plain', axis='both')

# --- Graphique 2 : Distribution des erreurs ---
plt.subplot(1, 2, 2)
errors_5 = y_test - y_pred
plt.hist(errors_5, bins=50, edgecolor='black')
plt.xlabel('Erreur de prédiction ($)')
plt.ylabel('Fréquence')
plt.title(f'Distribution des erreurs de prédiction (E[erreur]={mean_squared_error(y_test, y_pred)**0.5:.3f})')
plt.axvline(x=0, color='r', linestyle='--', linewidth=2)
plt.ticklabel_format(style='plain', axis='x')

plt.show()

# %% [markdown]
# On observe que l'on a beaucoup de mal à prédire les salaires élevés, on ne prédit aucun salaire > 35 Millions , pourtant les salaires réels augmentent quant à eux jusqu'à presque 60 Millions. On remarque aussi que l'erreur de prédiction est approximativement centrée sur 0, synonyme de prédiction sans biais. ( En effet, en moyenne l'erreur = 0  (errors.mean() == 0 ) )

# %% [markdown]
# Et si on utilisait le classement comme un proxy de la normalisation.

# %% [markdown]
# On a du mal à prédire les valeurs des salaires mais peut on prédire le classement des joueurs les mieux payés?

# %%
df['Salary_RANK'] = df.groupby('Season')['adjusted_salary'].rank(ascending = False)

tab_rank = df[['Salary_RANK','PLAYER_NAME','Season','adjusted_salary','PTS_RANK','REB_RANK','AST_RANK','STL_RANK','BLK_RANK']].sort_values(by='Salary_RANK', ascending=True)
tab_rank.head(10)  # On a plusieurs numéro 1, en effet il y en a pour chaque saison
# Out:
#       Salary_RANK    PLAYER_NAME   Season  adjusted_salary  PTS_RANK  \
# 601           1.0  Kevin Garnett  2000-01         36848000        16
# 604           1.0  Kevin Garnett  2003-04         49280000         4
# 603           1.0  Kevin Garnett  2002-03         45360000         9
# 602           1.0  Kevin Garnett  2001-02         40992000        21
# 607           1.0  Kevin Garnett  2007-08         37053017        45
# 608           1.0  Kevin Garnett  2008-09         37127901        66
# 606           1.0  Kevin Garnett  2006-07         33810000        17
# 957           1.0    Kobe Bryant  2010-11         36961312         5
# 960           1.0    Kobe Bryant  2013-14         42330789        84
# 5556          1.0  Stephen Curry  2023-24         55030552        11
#
#       REB_RANK  AST_RANK  STL_RANK  BLK_RANK
# 601          8        33        36        17
# 604          1        32        28        11
# 603          2        14        40        19
# 602          3        32        55        22
# 607         22        69        23        36
# 608         26        95        62        35
# 606          1        52        50        17
# 957         94        35        40       319
# 960        137        15        57       303
# 5556       139        49       200       229

# %%
reg5_rank_salaire = smf.ols('Salary_RANK ~ PTS + REB + AST + STL + BLK', data=df).fit()
df['rank_salary_predicted_5'] = reg5_rank_salaire.predict(df[['PTS','REB','AST','STL','BLK']])

# %%
# Visualiser les prédictions vs valeurs réelles
fig, axes = plt.subplots(1, 2, figsize=(16, 6))
plt.suptitle(f"RLM : Rang(Salaire) ~ PTS + REB + AST + STL + BLK ( R^2 = {reg5.rsquared:.2f}) ")

# Graphique 1: Qualité de la RLM
plot_rlm('rank_salary_predicted_5', axes[0], y = 'Salary_RANK' )

# Graphique 2: Distribution des erreurs
plot_error('rank_salary_predicted_5',axes[1], y = 'Salary_RANK' , nom_reg = " Rang(Salaire) ~ PTS + REB + AST + STL + BLK" )
# Out:
#  Statistiques des erreurs ( Rang(Salaire) ~ PTS + REB + AST + STL + BLK):
#    Erreur moyenne: $-0
#    Écart-type des erreurs: $79

# %% [markdown]
# En prédisant les classements des salaires en fonction des performances en valeurs, on obtient des rangs prédits négatifs, ce qui est impossible.
# Pour résoudre ce problème, on tente de considérer non plus les performances en termes absolus mais en termes relatifs. Pour ce faire on utilise les classements des joueursdans chaque statistiques et non plus leurs performances en tant que telle.

# %%
reg5_rank_rank = smf.ols('Salary_RANK ~ PTS_RANK + REB_RANK + AST_RANK + STL_RANK + BLK_RANK', data=df).fit()
df['rank_salary_predicted_5_rank'] = reg5_rank_rank.predict(df[['PTS_RANK','REB_RANK','AST_RANK','STL_RANK','BLK_RANK']])

# %%
# Visualiser les prédictions vs valeurs réelles
fig, axes = plt.subplots(1, 2, figsize=(16, 6))
plt.suptitle(f"RLM : Rang(Salaire) ~ Rang(PTS + REB + AST + STL + BLK)( R^2 = {reg5.rsquared:.2f}) ")

# Graphique 1: Qualité de la RLM
plot_rlm('rank_salary_predicted_5_rank', axes[0], y = 'Salary_RANK' )

# Graphique 2: Distribution des erreurs
plot_error('rank_salary_predicted_5_rank',axes[1], y = 'Salary_RANK' )
# Out:
#  Statistiques des erreurs ():
#    Erreur moyenne: $0
#    Écart-type des erreurs: $79
